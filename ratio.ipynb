# %%
import pandas as pd
CD_DTG = pd.read_csv("/home/user/jin_jb/DTG/DATA/CD_DTG.csv")

CD_DTG
# Out:
#      TRANSCO_CD  Speeding  Long-term speeding  Sudden acceleration  \
# 0          1375    545260                   0              3282864
# 1          1386    179172                   0              2900419
# 2          1376    225128                   0              2908411
# 3          1373    183506                   0              2851735
# 4          1384    361202                   0              2266239
# ...         ...       ...                 ...                  ...
# 6248      28284         0                   0                    0
# 6249      43665         0                   0                    0
# 6250     132834         0                   0                    0
# 6251     135776         0                   0                    0
# 6252      30231         0                   0                    0
#
#       Sudden start  Sudden deceleration  Sudden stop  Sudden left turn  \
# 0              142              1492254       319892            459568
# 1              172              1214898       360479            395524
# 2              572               985675       235202            361650
# 3              756               995762       245403            333730
# 4               33              1197247       315906            416765
# ...            ...                  ...          ...               ...
# 6248             0                    0            0                 0
# 6249             0                    0            0                 0
# 6250             0                    0            0                 0
# 6251             0                    0            0                 0
# 6252             0                    0            0                 0
#
#       Sudden right turn  Sudden U-turn  Sudden overtaking  Sudden lane change  \
# 0                262886          29161             229274              602963
# 1                239466          31662             178486              607664
# 2                205016          49051             187122              660407
# 3                182160          21659             204999              716121
# 4                230364          89193             150240              686505
# ...                 ...            ...                ...                 ...
# 6248                  0              0                  0                   0
# 6249                  0              0                  0                   0
# 6250                  0              0                  0                   0
# 6251                  0              0                  0                   0
# 6252                  0              0                  0                   0
#
#       Total_Sum
# 0       7224264
# 1       6107942
# 2       5818234
# 3       5735831
# 4       5713694
# ...         ...
# 6248          0
# 6249          0
# 6250          0
# 6251          0
# 6252          0
#
# [6253 rows x 13 columns]

# %%
len(CD_DTG['TRANSCO_CD'].unique())
# Out:
# 6253

# %%
import pandas as pd
DMS_STATB_CORP01 = pd.read_csv("/home/user/jin_jb/DTG/DATA/AI모델자료/DMS_STATB_CORP01.csv", sep="\t", encoding='UTF-8')
DMS_STATB_CORP01[['CORP_CD','CORP_NM']]
# Out:
#        CORP_CD   CORP_NM
# 0         1373      대전버스
# 1         1374      경익운수
# 2         1375      선진여객
# 3         1376      협진운수
# 4         1377      대전교통
# ...        ...       ...
# 82228    32733    쌍마네트워크
# 82229    32901   은혜통운(주)
# 82230    33875  (주)코끼리물류
# 82231    33876  (주)참다운물류
# 82232    33889  (주)비케이운수
#
# [82233 rows x 2 columns]

# %% [markdown]
# ##### CORP_CD = 업체코드, STOP_YMD_FROM = 면허정지기간시작, STOP_YMD_TO = 면허정지기간종료, STOP_DAY = 정지기간, CANCEL_YMD = 면허취소일자, CANCEL_CAUSE = 면허취소사유, RECALL_YMD = 운전면허복귀일자, RETRACTION_CAUSE = 면허취소철회사유

# %%
import pandas as pd
DMS_TRATB_SAGO01 = pd.read_csv("/home/user/jin_jb/DTG/DATA/AI모델자료/DMS_TRATB_SAGO01.csv", sep="\t", encoding = 'UTF-8')

DMS_TRATB_SAGO01 = DMS_TRATB_SAGO01[['CORP_CD','STOP_YMD_FROM','STOP_YMD_TO','STOP_DAY','CANCEL_YMD','CANCEL_CAUSE','RECALL_YMD','RETRACTION_CAUSE']]

DMS_TRATB_SAGO01
# Out:
# /tmp/ipykernel_2726319/2766178026.py:2: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   DMS_TRATB_SAGO01 = pd.read_csv("/home/user/jin_jb/DTG/DATA/AI모델자료/DMS_TRATB_SAGO01.csv", sep="\t", encoding = 'UTF-8')
#         CORP_CD  STOP_YMD_FROM  STOP_YMD_TO  STOP_DAY  CANCEL_YMD  \
# 0          3217            NaN          NaN       NaN  19981013.0
# 1          1376            NaN          NaN       NaN  19910222.0
# 2          1374            NaN          NaN       NaN  19860107.0
# 3          1380            NaN          NaN       NaN  20040522.0
# 4          3219            NaN          NaN       NaN  19971227.0
# ...         ...            ...          ...       ...         ...
# 116479    28626            NaN          NaN       NaN         NaN
# 116480    17792            NaN          NaN       NaN         NaN
# 116481     4522            NaN          NaN       NaN         NaN
# 116482    17816            NaN          NaN       NaN         NaN
# 116483    15666            NaN          NaN       NaN  20210519.0
#
#         CANCEL_CAUSE  RECALL_YMD  RETRACTION_CAUSE
# 0            30101.0         NaN               NaN
# 1            30701.0         NaN               NaN
# 2            30701.0         NaN               NaN
# 3            33001.0         NaN               NaN
# 4            30101.0         NaN               NaN
# ...              ...         ...               ...
# 116479           NaN         NaN               NaN
# 116480           NaN         NaN               NaN
# 116481           NaN         NaN               NaN
# 116482           NaN         NaN               NaN
# 116483       33001.0         NaN               NaN
#
# [116484 rows x 8 columns]

# %%
len(DMS_TRATB_SAGO01['CORP_CD'].unique())
# Out:
# 686

# %%
print(CD_DTG['TRANSCO_CD'].dtype)
print(DMS_TRATB_SAGO01['CORP_CD'].dtype)
# Out:
# object
# int64

# %%
import pandas as pd
import numpy as np

# 비정수 값을 NaN으로 대체
CD_DTG['TRANSCO_CD'] = pd.to_numeric(CD_DTG['TRANSCO_CD'], errors='coerce')

# NaN 값을 제거
CD_DTG = CD_DTG.dropna(subset=['TRANSCO_CD'])

# 이제 안전하게 정수형으로 변환 가능
CD_DTG['TRANSCO_CD'] = CD_DTG['TRANSCO_CD'].astype(int)


# DMS_TRATB_SAGO01에서 고유한 CORP_CD 값을 추출
transco_cd_list = DMS_TRATB_SAGO01['CORP_CD'].unique()

# CD_DTG에서 TRANSCO_CD가 transco_cd_list에 속하는 행만 필터링
filtered_cd_dtg = CD_DTG[CD_DTG['TRANSCO_CD'].isin(transco_cd_list)]

# 필터링된 결과 확인
filtered_cd_dtg.reset_index(drop = True, inplace = True)
filtered_cd_dtg
# Out:
# /tmp/ipykernel_2726319/1743091570.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CD_DTG['TRANSCO_CD'] = CD_DTG['TRANSCO_CD'].astype(int)
#      TRANSCO_CD  Speeding  Long-term speeding  Sudden acceleration  \
# 0          1375    545260                   0              3282864
# 1          1386    179172                   0              2900419
# 2          1376    225128                   0              2908411
# 3          1373    183506                   0              2851735
# 4          1384    361202                   0              2266239
# ..          ...       ...                 ...                  ...
# 207       14847         1                   0                    3
# 208       14263         0                   0                    6
# 209        6302         2                   0                    0
# 210       37361         1                   0                    0
# 211       24970         0                   0                    0
#
#      Sudden start  Sudden deceleration  Sudden stop  Sudden left turn  \
# 0             142              1492254       319892            459568
# 1             172              1214898       360479            395524
# 2             572               985675       235202            361650
# 3             756               995762       245403            333730
# 4              33              1197247       315906            416765
# ..            ...                  ...          ...               ...
# 207             0                    0            6                 0
# 208             0                    1            0                 0
# 209             0                    0            0                 0
# 210             0                    0            0                 0
# 211             0                    0            0                 0
#
#      Sudden right turn  Sudden U-turn  Sudden overtaking  Sudden lane change  \
# 0               262886          29161             229274              602963
# 1               239466          31662             178486              607664
# 2               205016          49051             187122              660407
# 3               182160          21659             204999              716121
# 4               230364          89193             150240              686505
# ..                 ...            ...                ...                 ...
# 207                  0              0                  0                   0
# 208                  0              0                  0                   2
# 209                  0              0                  0                   0
# 210                  0              0                  0                   0
# 211                  0              0                  0                   1
#
#      Total_Sum
# 0      7224264
# 1      6107942
# 2      5818234
# 3      5735831
# 4      5713694
# ..         ...
# 207         10
# 208          9
# 209          2
# 210          1
# 211          1
#
# [212 rows x 13 columns]

# %%
transco_cd_values = filtered_cd_dtg['TRANSCO_CD']

# CORP_CD가 transco_cd_values에 속하는 행만 필터링
DMS_TRATB_SAGO = DMS_TRATB_SAGO01[DMS_TRATB_SAGO01['CORP_CD'].isin(transco_cd_values)]

DMS_TRATB_SAGO = DMS_TRATB_SAGO[DMS_TRATB_SAGO['CORP_CD']!=15666]

DMS_TRATB_SAGO
# Out:
#         CORP_CD  STOP_YMD_FROM  STOP_YMD_TO  STOP_DAY  CANCEL_YMD  \
# 1          1376            NaN          NaN       NaN  19910222.0
# 2          1374            NaN          NaN       NaN  19860107.0
# 3          1380            NaN          NaN       NaN  20040522.0
# 5          1374            NaN          NaN       NaN  19900328.0
# 6         12801            NaN          NaN       NaN  20110730.0
# ...         ...            ...          ...       ...         ...
# 116476     1383            NaN          NaN       NaN         NaN
# 116478    17826            NaN          NaN       NaN         NaN
# 116479    28626            NaN          NaN       NaN         NaN
# 116480    17792            NaN          NaN       NaN         NaN
# 116482    17816            NaN          NaN       NaN         NaN
#
#         CANCEL_CAUSE  RECALL_YMD  RETRACTION_CAUSE
# 1            30701.0         NaN               NaN
# 2            30701.0         NaN               NaN
# 3            33001.0         NaN               NaN
# 5            31101.0         NaN               NaN
# 6            33001.0         NaN               NaN
# ...              ...         ...               ...
# 116476           NaN         NaN               NaN
# 116478           NaN         NaN               NaN
# 116479           NaN         NaN               NaN
# 116480           NaN         NaN               NaN
# 116482           NaN         NaN               NaN
#
# [74085 rows x 8 columns]

# %%
len(DMS_TRATB_SAGO['CORP_CD'].unique())
# Out:
# 211

# %%
import pandas as pd

A = DMS_TRATB_SAGO.copy()

# 면허정지와 면허취소 날짜가 있는 행을 확인
A['has_stop'] = A['STOP_YMD_FROM'].notna()
A['has_cancel'] = A['CANCEL_YMD'].notna()

# 운수회사별로 면허정지와 면허취소의 개수를 집계
result = A.groupby('CORP_CD').agg(
    stop_count=('has_stop', 'sum'),
    cancel_count=('has_cancel', 'sum')
)

# 면허정지와 면허취소의 총 개수를 계산
result['total_count'] = result['stop_count'] + result['cancel_count']

result = result.sort_values(['total_count'],ascending = False).reset_index()

# result = result.iloc[1:].reset_index(drop= True)

result
# Out:
#      CORP_CD  stop_count  cancel_count  total_count
# 0       1373         161            33          194
# 1      17830         152            39          191
# 2       1375         129            39          168
# 3       1384         136            24          160
# 4       1386         130            27          157
# ..       ...         ...           ...          ...
# 206    29993           0             0            0
# 207    29708           0             0            0
# 208    25677           0             0            0
# 209    23212           0             0            0
# 210    38279           0             0            0
#
# [211 rows x 4 columns]

# %%
# DF = pd.merge(ratio, result[['CORP_CD','total_count']], left_on='TRANSCO_CD', right_on = 'CORP_CD', how='inner')
# DF.drop('CORP_CD', axis=1, inplace = True)
# DF = DF.rename(columns={'TRANSCO_CD': 'CORP_CD'})
# DF

# %%
import pandas as pd 
ratio = pd.read_csv("/home/user/jin_jb/DTG/DATA/ratio.csv")
ratio
# Out:
#      TRANSCO_CD  Total_Sum  CAR_REG_NO         ratio  bubble_size
# 0          1375    7224264         104  69464.076923   694.640769
# 1          1386    6107942          92  66390.673913   663.906739
# 2          1376    5818234          89  65373.415730   653.734157
# 3          1380    3692614          65  56809.446154   568.094462
# 4          1373    5735831         101  56790.405941   567.904059
# ..          ...        ...         ...           ...          ...
# 211       14263          9           1      9.000000     0.090000
# 212       32945          4           1      4.000000     0.040000
# 213        6302          2           2      1.000000     0.010000
# 214       37361          1           1      1.000000     0.010000
# 215       24970          1           1      1.000000     0.010000
#
# [216 rows x 5 columns]

# %%
# #15666이 문제여서 아예 제거
# ratio = ratio[ratio['TRANSCO_CD']!=15666]
# ratio.to_csv("/home/user/jin_jb/DTG/DATA/ratio.csv", index_label = False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 비율(ratio) 열을 계산합니다: 위험운전 횟수 / 차량 등록 개수
ratio['ratio'] = ratio['Total_Sum'] / ratio['CAR_REG_NO']

# 버블 크기를 위한 스케일링 팩터 (버블 크기가 적절한지 확인하고 조정할 수 있습니다)
size_scaling_factor = 0.01

# 색상을 위한 스케일링 (버블 색상이 적절한지 확인하고 조정할 수 있습니다)
color_scaling_factor = 100

# 버블 크기 설정
ratio['bubble_size'] = ratio['ratio'] * size_scaling_factor

# 버블 차트 그리기
plt.figure(figsize=(14, 8))
scatter = plt.scatter('CAR_REG_NO', 'Total_Sum', 
                      s='bubble_size', 
                      c='ratio', 
                      cmap='Reds', 
                      alpha=0.6, 
                      data=ratio)

from matplotlib.ticker import FuncFormatter

# 천 단위로 쉼표를 추가하는 함수
def thousand_separator(x, pos):
    return '{:,.0f}'.format(x)

cbar = plt.colorbar(scatter)
cbar.set_label('Ratio of Risky Behavior to Cars', rotation=90, labelpad=15)

# FuncFormatter를 사용하여 컬러 바의 숫자 형식을 변경
cbar.formatter = FuncFormatter(thousand_separator)
cbar.update_ticks()
plt.xlabel('Number of Registered Cars')
plt.ylabel('Total Number of Risky Driving Behavior')
# plt.title('Bubble Chart of Dangerous Driving Instances per Registered Car')

plt.grid(False)
plt.show()

# %%
import pandas as pd

# 각 구간별 경계 인덱스 계산
total = len(ratio)
boundaries = {
    'Grouped_A': int(total * 0.1),  # 상위 10%
    'Grouped_B': int(total * 0.3),  # 상위 30%
    'Grouped_C': int(total * 0.5),  # 상위 50%
    'Grouped_D': int(total * 0.7),  # 상위 70%
    'Grouped_E': total              # 나머지
}

# 각 구간별로 그룹 할당
# labels = ['Grouped_E', 'Grouped_D', 'Grouped_C', 'Grouped_B', 'Grouped_A']
labels = ['Grouped_A', 'Grouped_B', 'Grouped_C', 'Grouped_D', 'Grouped_E']
ratio['Group'] = pd.cut(ratio.index + 1, bins=[0] + list(boundaries.values()), labels=labels, right=True)

ratio
# Out:
#      TRANSCO_CD  Total_Sum  CAR_REG_NO         ratio  bubble_size      Group
# 0          1375    7224264         104  69464.076923   694.640769  Grouped_A
# 1          1386    6107942          92  66390.673913   663.906739  Grouped_A
# 2          1376    5818234          89  65373.415730   653.734157  Grouped_A
# 3          1380    3692614          65  56809.446154   568.094462  Grouped_A
# 4          1373    5735831         101  56790.405941   567.904059  Grouped_A
# ..          ...        ...         ...           ...          ...        ...
# 211       14263          9           1      9.000000     0.090000  Grouped_E
# 212       32945          4           1      4.000000     0.040000  Grouped_E
# 213        6302          2           2      1.000000     0.010000  Grouped_E
# 214       37361          1           1      1.000000     0.010000  Grouped_E
# 215       24970          1           1      1.000000     0.010000  Grouped_E
#
# [216 rows x 6 columns]

# %%
print(len(ratio[ratio['Group'] == 'Grouped_A']))
print(len(ratio[ratio['Group'] == 'Grouped_B']))
print(len(ratio[ratio['Group'] == 'Grouped_C']))
print(len(ratio[ratio['Group'] == 'Grouped_D']))
print(len(ratio[ratio['Group'] == 'Grouped_E']))
# Out:
# 21
# 43
# 44
# 43
# 65

# %% [markdown]
# ### Grouped_A

# %%
Grouped_a = ratio[ratio['Group']=='Grouped_A']

# 필터링된 행의 'TRANSCO_CD' 추출
Grouped_A = Grouped_a['TRANSCO_CD'].tolist()

print(len(Grouped_A))
print(Grouped_A)
# Out:
# 21
# [1375, 1386, 1376, 1380, 1373, 28814, 1378, 1382, 25288, 1384, 1383, 1374, 1381, 17830, 1385, 1377, 14316, 29993, 24621, 33238, 14741]

# %%
# 필터링된 결과를 저장할 빈 리스트 초기화
filtered_frames = []

# 각 'CORP_CD'에 대해 필터링 수행
for corp_cd in Grouped_A:
    # 'corp_cd'를 정수로 처리하여 현재 'CORP_CD'에 해당하는 행 필터링
    temp_df = DMS_TRATB_SAGO[(DMS_TRATB_SAGO['CORP_CD'] == corp_cd)]
    
    # 결과가 비어있지 않다면 리스트에 추가
    if not temp_df.empty:
        filtered_frames.append(temp_df)

# 모든 필터링된 결과를 하나의 DataFrame으로 합치기
license_A = pd.concat(filtered_frames)

# 결과 출력
print(f"Grouped_A의 등록된 개수: {len(license_A)}")
print(f"Grouped_A의 등록된 운수회사 개수: {len(license_A['CORP_CD'].unique())}")
print(f"Grouped_A의 면허 정지 개수: {len(license_A[license_A['STOP_YMD_FROM'].notnull()])}")
print(f"Grouped_A의 면허 취소 개수: {len(license_A[license_A['CANCEL_YMD'].notnull()])}")
print(f"Grouped_A의 면허 취소 철회 개수: {len(license_A[license_A['RECALL_YMD'].notna() & license_A['CANCEL_YMD'].notna()])}")
license_A.reset_index(drop=True)
# Out:
# Grouped_A의 등록된 개수: 18931
# Grouped_A의 등록된 운수회사 개수: 21
# Grouped_A의 면허 정지 개수: 1463
# Grouped_A의 면허 취소 개수: 371
# Grouped_A의 면허 취소 철회 개수: 53
#        CORP_CD  STOP_YMD_FROM  STOP_YMD_TO  STOP_DAY  CANCEL_YMD  \
# 0         1375            NaN          NaN       NaN         NaN
# 1         1375            NaN          NaN       NaN         NaN
# 2         1375            NaN          NaN       NaN         NaN
# 3         1375            NaN          NaN       NaN         NaN
# 4         1375            NaN          NaN       NaN  20050524.0
# ...        ...            ...          ...       ...         ...
# 18926    14741            NaN          NaN       NaN         NaN
# 18927    14741            NaN          NaN       NaN         NaN
# 18928    14741            NaN          NaN       NaN         NaN
# 18929    14741            NaN          NaN       NaN         NaN
# 18930    14741            NaN          NaN       NaN         NaN
#
#        CANCEL_CAUSE  RECALL_YMD  RETRACTION_CAUSE
# 0               NaN         NaN               NaN
# 1               NaN         NaN               NaN
# 2               NaN         NaN               NaN
# 3               NaN         NaN               NaN
# 4           32301.0         NaN               NaN
# ...             ...         ...               ...
# 18926           NaN         NaN               NaN
# 18927           NaN         NaN               NaN
# 18928           NaN         NaN               NaN
# 18929           NaN         NaN               NaN
# 18930           NaN         NaN               NaN
#
# [18931 rows x 8 columns]

# %% [markdown]
# ### Grouped_B

# %%
Grouped_b = ratio[ratio['Group']=='Grouped_B']

# 필터링된 행의 'TRANSCO_CD' 추출
Grouped_B = Grouped_b['TRANSCO_CD'].tolist()

print(len(Grouped_B))
print(Grouped_B)
# Out:
# 43
# [14188, 14798, 25944, 29454, 3212, 3227, 3209, 23112, 26019, 28882, 33436, 24636, 3214, 3232, 22478, 25321, 23212, 14731, 24249, 23536, 25565, 42644, 22098, 25959, 14823, 14308, 29828, 30342, 22477, 3211, 22308, 17812, 14046, 17821, 17808, 17826, 33770, 17848, 17797, 17818, 17773, 17807, 33578]

# %%
# 필터링된 결과를 저장할 빈 리스트 초기화
filtered_frames = []

# 각 'CORP_CD'에 대해 필터링 수행
for corp_cd in Grouped_B:
    # 'corp_cd'를 정수로 처리하여 현재 'CORP_CD'에 해당하는 행 필터링
    temp_df = DMS_TRATB_SAGO[(DMS_TRATB_SAGO['CORP_CD'] == corp_cd)]
    
    # 결과가 비어있지 않다면 리스트에 추가
    if not temp_df.empty:
        filtered_frames.append(temp_df)

# 모든 필터링된 결과를 하나의 DataFrame으로 합치기
license_B = pd.concat(filtered_frames)

# 결과 출력
print(f"Grouped_B의 등록된 개수: {len(license_B)}")
print(f"Grouped_B의 등록된 운수회사 개수: {len(license_B['CORP_CD'].unique())}")
print(f"Grouped_B의 면허 정지 개수: {len(license_B[license_B['STOP_YMD_FROM'].notnull()])}")
print(f"Grouped_B의 면허 취소 개수: {len(license_B[license_B['CANCEL_YMD'].notnull()])}")
print(f"Grouped_B의 면허 취소 철회 개수: {len(license_B[license_B['RECALL_YMD'].notna() & license_B['CANCEL_YMD'].notna()])}")
license_B.reset_index(drop=True)
# Out:
# Grouped_B의 등록된 개수: 7522
# Grouped_B의 등록된 운수회사 개수: 42
# Grouped_B의 면허 정지 개수: 737
# Grouped_B의 면허 취소 개수: 249
# Grouped_B의 면허 취소 철회 개수: 48
#       CORP_CD  STOP_YMD_FROM  STOP_YMD_TO  STOP_DAY  CANCEL_YMD  CANCEL_CAUSE  \
# 0       14188            NaN          NaN       NaN         NaN           NaN
# 1       14188            NaN          NaN       NaN         NaN           NaN
# 2       14188            NaN          NaN       NaN         NaN           NaN
# 3       14188            NaN          NaN       NaN         NaN           NaN
# 4       14188            NaN          NaN       NaN  20041214.0       31101.0
# ...       ...            ...          ...       ...         ...           ...
# 7517    33578            NaN          NaN       NaN         NaN           NaN
# 7518    33578     20170927.0   20170927.0       0.0         NaN           NaN
# 7519    33578            NaN          NaN       NaN         NaN           NaN
# 7520    33578            NaN          NaN       NaN         NaN           NaN
# 7521    33578            NaN          NaN       NaN         NaN           NaN
#
#       RECALL_YMD  RETRACTION_CAUSE
# 0            NaN               NaN
# 1            NaN               NaN
# 2            NaN               NaN
# 3            NaN               NaN
# 4            NaN               NaN
# ...          ...               ...
# 7517         NaN               NaN
# 7518         NaN               NaN
# 7519         NaN               NaN
# 7520         NaN               NaN
# 7521         NaN               NaN
#
# [7522 rows x 8 columns]

# %% [markdown]
# ### Grouped_C

# %%
Grouped_c = ratio[ratio['Group']=='Grouped_C']

# 필터링된 행의 'TRANSCO_CD' 추출
Grouped_C = Grouped_c['TRANSCO_CD'].tolist()

print(len(Grouped_C))
print(Grouped_C)
# Out:
# 44
# [24773, 17834, 17782, 17828, 14750, 17804, 17841, 28994, 23221, 17816, 17771, 17779, 14763, 17793, 17792, 17823, 17827, 17846, 17774, 17777, 17810, 17775, 17803, 17809, 17839, 17778, 33011, 25568, 17833, 17791, 17811, 17835, 17802, 17814, 17815, 17799, 17784, 14717, 14366, 17838, 17832, 17842, 17836, 17845]

# %%
# 필터링된 결과를 저장할 빈 리스트 초기화
filtered_frames = []

# 각 'CORP_CD'에 대해 필터링 수행
for corp_cd in Grouped_C:
    # 'corp_cd'를 정수로 처리하여 현재 'CORP_CD'에 해당하는 행 필터링
    temp_df = DMS_TRATB_SAGO[(DMS_TRATB_SAGO['CORP_CD'] == corp_cd)]
    
    # 결과가 비어있지 않다면 리스트에 추가
    if not temp_df.empty:
        filtered_frames.append(temp_df)

# 모든 필터링된 결과를 하나의 DataFrame으로 합치기
license_C = pd.concat(filtered_frames)

# 결과 출력
print(f"Grouped_C의 등록된 개수: {len(license_C)}")
print(f"Grouped_C의 등록된 운수회사 개수: {len(license_C['CORP_CD'].unique())}")
print(f"Grouped_C의 면허 정지 개수: {len(license_C[license_C['STOP_YMD_FROM'].notnull()])}")
print(f"Grouped_C의 면허 취소 개수: {len(license_C[license_C['CANCEL_YMD'].notnull()])}")
print(f"Grouped_C의 면허 취소 철회 개수: {len(license_C[license_C['RECALL_YMD'].notna() & license_C['CANCEL_YMD'].notna()])}")
license_C.reset_index(drop=True)
# Out:
# Grouped_C의 등록된 개수: 21119
# Grouped_C의 등록된 운수회사 개수: 42
# Grouped_C의 면허 정지 개수: 1937
# Grouped_C의 면허 취소 개수: 643
# Grouped_C의 면허 취소 철회 개수: 83
#        CORP_CD  STOP_YMD_FROM  STOP_YMD_TO  STOP_DAY  CANCEL_YMD  \
# 0        24773            NaN          NaN       NaN         NaN
# 1        24773            NaN          NaN       NaN         NaN
# 2        24773            NaN          NaN       NaN         NaN
# 3        24773            NaN          NaN       NaN         NaN
# 4        24773            NaN          NaN       NaN         NaN
# ...        ...            ...          ...       ...         ...
# 21114    17845            NaN          NaN       NaN         NaN
# 21115    17845            NaN          NaN       NaN         NaN
# 21116    17845            NaN          NaN       NaN         NaN
# 21117    17845            NaN          NaN       NaN         NaN
# 21118    17845            NaN          NaN       NaN         NaN
#
#        CANCEL_CAUSE  RECALL_YMD  RETRACTION_CAUSE
# 0               NaN         NaN               NaN
# 1               NaN  20161118.0               NaN
# 2               NaN         NaN               NaN
# 3               NaN         NaN               NaN
# 4               NaN         NaN               NaN
# ...             ...         ...               ...
# 21114           NaN         NaN               NaN
# 21115           NaN         NaN               NaN
# 21116           NaN         NaN               NaN
# 21117           NaN         NaN               NaN
# 21118           NaN         NaN               NaN
#
# [21119 rows x 8 columns]

# %% [markdown]
# ### Grouped_D

# %%
Grouped_d = ratio[ratio['Group']=='Grouped_D']

# 필터링된 행의 'TRANSCO_CD' 추출
Grouped_D = Grouped_d['TRANSCO_CD'].tolist()

print(len(Grouped_D))
print(Grouped_D)
# Out:
# 43
# [17817, 17813, 17801, 17788, 17780, 17819, 17844, 17800, 17786, 14057, 17837, 17795, 17806, 17829, 17796, 26749, 17783, 17776, 17789, 17794, 17822, 17849, 14774, 17785, 3237, 17824, 17772, 12801, 17825, 17790, 38279, 17805, 14831, 17787, 17843, 31075, 14313, 17847, 27203, 17840, 3241, 27206, 17831]

# %%
# 필터링된 결과를 저장할 빈 리스트 초기화
filtered_frames = []

# 각 'CORP_CD'에 대해 필터링 수행
for corp_cd in Grouped_D:
    # 'corp_cd'를 정수로 처리하여 현재 'CORP_CD'에 해당하는 행 필터링
    temp_df = DMS_TRATB_SAGO[(DMS_TRATB_SAGO['CORP_CD'] == corp_cd)]
    
    # 결과가 비어있지 않다면 리스트에 추가
    if not temp_df.empty:
        filtered_frames.append(temp_df)

# 모든 필터링된 결과를 하나의 DataFrame으로 합치기
license_D = pd.concat(filtered_frames)

# 결과 출력
print(f"Grouped_D의 등록된 개수: {len(license_D)}")
print(f"Grouped_D의 등록된 운수회사 개수: {len(license_D['CORP_CD'].unique())}")
print(f"Grouped_D의 면허 정지 개수: {len(license_D[license_D['STOP_YMD_FROM'].notnull()])}")
print(f"Grouped_D의 면허 취소 개수: {len(license_D[license_D['CANCEL_YMD'].notnull()])}")
print(f"Grouped_D의 면허 취소 철회 개수: {len(license_D[license_D['RECALL_YMD'].notna() & license_D['CANCEL_YMD'].notna()])}")
license_D.reset_index(drop=True)
# Out:
# Grouped_D의 등록된 개수: 19261
# Grouped_D의 등록된 운수회사 개수: 43
# Grouped_D의 면허 정지 개수: 1765
# Grouped_D의 면허 취소 개수: 531
# Grouped_D의 면허 취소 철회 개수: 58
#        CORP_CD  STOP_YMD_FROM  STOP_YMD_TO  STOP_DAY  CANCEL_YMD  \
# 0        17817            NaN          NaN       NaN         NaN
# 1        17817            NaN          NaN       NaN         NaN
# 2        17817            NaN          NaN       NaN         NaN
# 3        17817            NaN          NaN       NaN         NaN
# 4        17817            NaN          NaN       NaN         NaN
# ...        ...            ...          ...       ...         ...
# 19256    17831            NaN          NaN       NaN         NaN
# 19257    17831            NaN          NaN       NaN         NaN
# 19258    17831            NaN          NaN       NaN         NaN
# 19259    17831            NaN          NaN       NaN         NaN
# 19260    17831            NaN          NaN       NaN         NaN
#
#        CANCEL_CAUSE  RECALL_YMD  RETRACTION_CAUSE
# 0               NaN         NaN               NaN
# 1               NaN         NaN               NaN
# 2               NaN         NaN               NaN
# 3               NaN         NaN               NaN
# 4               NaN         NaN               NaN
# ...             ...         ...               ...
# 19256           NaN         NaN               NaN
# 19257           NaN         NaN               NaN
# 19258           NaN         NaN               NaN
# 19259           NaN         NaN               NaN
# 19260           NaN         NaN               NaN
#
# [19261 rows x 8 columns]

# %% [markdown]
# ### Grouped_E

# %%
Grouped_e = ratio[ratio['Group']=='Grouped_E']

# 필터링된 행의 'TRANSCO_CD' 추출
Grouped_E = Grouped_e['TRANSCO_CD'].tolist()

print(len(Grouped_E))
print(Grouped_E)
# Out:
# 65
# [24638, 14795, 31351, 14735, 22540, 14304, 34918, 24971, 24635, 14258, 25661, 14165, 14726, 28626, 35261, 32526, 14071, 14746, 22964, 22461, 10917, 14043, 24335, 14072, 14749, 14759, 14065, 29708, 24679, 29591, 14736, 14770, 14734, 3235, 25677, 14327, 22199, 14323, 14107, 14309, 14790, 14055, 14769, 35995, 24640, 23236, 10205, 14371, 14311, 36733, 24637, 14475, 23534, 33889, 37521, 34242, 34957, 24451, 14255, 14847, 14263, 32945, 6302, 37361, 24970]

# %%
# 필터링된 결과를 저장할 빈 리스트 초기화
filtered_frames = []

# 각 'CORP_CD'에 대해 필터링 수행
for corp_cd in Grouped_E:
    # 'corp_cd'를 정수로 처리하여 현재 'CORP_CD'에 해당하는 행 필터링
    temp_df = DMS_TRATB_SAGO[(DMS_TRATB_SAGO['CORP_CD'] == corp_cd)]
    
    # 결과가 비어있지 않다면 리스트에 추가
    if not temp_df.empty:
        filtered_frames.append(temp_df)

# 모든 필터링된 결과를 하나의 DataFrame으로 합치기
license_E = pd.concat(filtered_frames)

# 결과 출력
print(f"Grouped_E의 등록된 개수: {len(license_E)}")
print(f"Grouped_E의 등록된 운수회사 개수: {len(license_E['CORP_CD'].unique())}")
print(f"Grouped_E의 면허 정지 개수: {len(license_E[license_E['STOP_YMD_FROM'].notnull()])}")
print(f"Grouped_E의 면허 취소 개수: {len(license_E[license_E['CANCEL_YMD'].notnull()])}")
print(f"Grouped_E의 면허 취소 철회 개수: {len(license_E[license_E['RECALL_YMD'].notna() & license_E['CANCEL_YMD'].notna()])}")
license_E.reset_index(drop=True)
# Out:
# Grouped_E의 등록된 개수: 7252
# Grouped_E의 등록된 운수회사 개수: 63
# Grouped_E의 면허 정지 개수: 714
# Grouped_E의 면허 취소 개수: 370
# Grouped_E의 면허 취소 철회 개수: 80
#       CORP_CD  STOP_YMD_FROM  STOP_YMD_TO  STOP_DAY  CANCEL_YMD  CANCEL_CAUSE  \
# 0       24638            NaN          NaN       NaN         NaN           NaN
# 1       24638            NaN          NaN       NaN         NaN           NaN
# 2       24638            NaN          NaN       NaN         NaN           NaN
# 3       24638            NaN          NaN       NaN         NaN           NaN
# 4       24638            NaN          NaN       NaN         NaN           NaN
# ...       ...            ...          ...       ...         ...           ...
# 7247    24970            NaN          NaN       NaN         NaN           NaN
# 7248    24970     20160712.0   20160712.0       0.0         NaN           NaN
# 7249    24970            NaN          NaN       NaN         NaN           NaN
# 7250    24970            NaN          NaN       NaN         NaN           NaN
# 7251    24970            NaN          NaN       NaN         NaN           NaN
#
#       RECALL_YMD  RETRACTION_CAUSE
# 0            NaN               NaN
# 1            NaN               NaN
# 2            NaN               NaN
# 3            NaN               NaN
# 4            NaN               NaN
# ...          ...               ...
# 7247         NaN               NaN
# 7248         NaN               NaN
# 7249         NaN               NaN
# 7250         NaN               NaN
# 7251         NaN               NaN
#
# [7252 rows x 8 columns]

# %% [markdown]
# ## Grouped_A 현재경력, 전체경력, 나이

# %%
import pandas as pd
DMS_STATB_CORP02 = pd.read_csv("/home/user/jin_jb/DTG/DATA/AI모델자료/DMS_STATB_CORP02.csv", sep="\t", encoding='UTF-8')

# %%
# 필터링된 결과를 저장할 빈 리스트 초기화
filtered_frames = []

# 각 'CORP_CD'에 대해 필터링 수행
for corp_cd in Grouped_A:
    # 현재 'CORP_CD'에 해당하는 행 필터링
    temp_df = DMS_STATB_CORP02[(DMS_STATB_CORP02['CORP_CD'] == int(corp_cd)) & (DMS_STATB_CORP02['REPORT_YM'] == 201912)]
    
    # 결과가 비어있지 않고, 여러 행이 있다면 'TOT_CNT'가 최대인 행만 선택
    if not temp_df.empty:
        max_tot_cnt_row = temp_df[temp_df['TOT_CNT'] == temp_df['TOT_CNT'].max()]
        filtered_frames.append(max_tot_cnt_row)

# 모든 필터링된 결과를 하나의 DataFrame으로 합치기
Grouped_A_df = pd.concat(filtered_frames)

# 결과 출력
Grouped_A_df
# Out:
#        REPORT_YM  CORP_CD  FM_GUBUN  SIDO_CD UNION_CD REFER_CD   SGG_CD  \
# 66558     201912     1375         1  6300000  D010060  C000001  30230.0
# 66570     201912     1386         1  6300000  D010060  C000001  30230.0
# 66559     201912     1376         1  6300000  D010060  C000001  30200.0
# 66562     201912     1380         1  6300000  D010060  C000001  30110.0
# 66555     201912     1373         1  6300000  D010060  C000001  30140.0
# 70307     201912    28814         1  6300000  D060060  C000006  30200.0
# 66561     201912     1378         1  6300000  D010060  C000001  30200.0
# 66565     201912     1382         1  6300000  D010060  C000001  30230.0
# 69735     201912    25288         1  6300000  D030060  C000003  30140.0
# 66567     201912     1384         1  6300000  D010060  C000001  30110.0
# 66566     201912     1383         1  6300000  D010060  C000001  30200.0
# 66557     201912     1374         1  6300000  D010060  C000001  30200.0
# 66564     201912     1381         1  6300000  D010060  C000001  30230.0
# 69659     201912    17830         1  6300000  D020060  C000002  30170.0
# 66569     201912     1385         1  6300000  D010060  C000001  30230.0
# 66560     201912     1377         1  6300000  D010060  C000001  30140.0
# 68401     201912    14316         1  6300000  D080060  C000008  30230.0
# 70325     201912    29993         1  6300000  D030060  C000003  30170.0
# 69717     201912    24621         1  6300000  D080060  C000008  30230.0
# 70353     201912    33238         1  6300000  D030060  C000003  30170.0
# 68435     201912    14741         1  6300000  D080170  C000008  30140.0
#
#        NOW_CAREER00  NOW_CAREER01  NOW_CAREER02  ...  SCH12  SCH13  \
# 66558            34            32            22  ...      0    211
# 66570            30            32            17  ...      0    163
# 66559            41            19            12  ...      0    166
# 66562            26            12            14  ...      0    116
# 66555            42            14            19  ...      0    180
# 70307            12             3             4  ...      0     42
# 66561            34            18            20  ...      0    158
# 66565            15             6             9  ...      0     86
# 69735            12             8             3  ...      0     32
# 66567            38            26            25  ...      0    205
# 66566            26            16             8  ...      0     77
# 66557            27            22            23  ...      0    202
# 66564            25             5            16  ...      0     94
# 69659            16            14             4  ...      0     44
# 66569            13            13             7  ...      0     82
# 66560            38            19            12  ...      0    174
# 68401             7             4             3  ...      0     19
# 70325             6             1             4  ...      0     25
# 69717             9             1             4  ...      0     50
# 70353             2             3             5  ...      0     30
# 68435             8             1             3  ...      0     21
#
#        NOW_CAREER_AVG  TOT_CAREER_AVG  AGE_AVG  TOT_CNT  SYS_REG_ID  \
# 66558               7              14       51      258      system
# 66570               7              13       51      218      system
# 66559               6              14       53      204      system
# 66562               7              14       51      158      system
# 66555               7              13       49      236      system
# 70307               2              18       59       42      system
# 66561               6              11       49      182      system
# 66565               6              14       53      107      system
# 69735               2               9       57       32      system
# 66567               7              13       49      259      system
# 66566               7              15       53      105      system
# 66557               7              12       50      270      system
# 66564               5              12       50      110      system
# 69659               3              11       59       50      system
# 66569               6              16       54      101      system
# 66560               5              14       51      204      system
# 68401               2               6       47       19      system
# 70325               2               8       56       25      system
# 69717               6              12       52       57      system
# 70353               2               8       55       30      system
# 68435               3               7       46       21      system
#
#                      SYS_REG_DATE  ETL_RGST_ID                  ETL_REG_DT
# 66558  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66570  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66559  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66562  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66555  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70307  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66561  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66565  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69735  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66567  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66566  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66557  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66564  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69659  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66569  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66560  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68401  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70325  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69717  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70353  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68435  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
#
# [21 rows x 148 columns]

# %% [markdown]
# #### 현재경력 7:37

# %%
# columns = Grouped_A_df.columns.tolist()

# selected_columns = [columns[1]] + columns[7:37]

# Grouped_A_df.loc[:, selected_columns]

# %% [markdown]
# #### 전체경력 37:67

# %%
# columns = Grouped_A_df.columns.tolist()

# selected_columns = [columns[1]] + columns[37:67]

# Grouped_A_df.loc[:, selected_columns]

# %% [markdown]
# #### 나이 67:127

# %%
# columns = Grouped_A_df.columns.tolist()

# selected_columns = [columns[1]] + columns[67:127]

# Grouped_A_df.loc[:, selected_columns]

# %% [markdown]
# #### 평균 140:144

# %%
columns = Grouped_A_df.columns.tolist()

selected_columns = [columns[1]] + columns[140:144]

print(Grouped_A_df.iloc[:,140:144].mean())
Grouped_A_df.loc[:, selected_columns]
# Out:
# NOW_CAREER_AVG      5.000000
# TOT_CAREER_AVG     12.095238
# AGE_AVG            52.142857
# TOT_CNT           128.000000
# dtype: float64
#        CORP_CD  NOW_CAREER_AVG  TOT_CAREER_AVG  AGE_AVG  TOT_CNT
# 66558     1375               7              14       51      258
# 66570     1386               7              13       51      218
# 66559     1376               6              14       53      204
# 66562     1380               7              14       51      158
# 66555     1373               7              13       49      236
# 70307    28814               2              18       59       42
# 66561     1378               6              11       49      182
# 66565     1382               6              14       53      107
# 69735    25288               2               9       57       32
# 66567     1384               7              13       49      259
# 66566     1383               7              15       53      105
# 66557     1374               7              12       50      270
# 66564     1381               5              12       50      110
# 69659    17830               3              11       59       50
# 66569     1385               6              16       54      101
# 66560     1377               5              14       51      204
# 68401    14316               2               6       47       19
# 70325    29993               2               8       56       25
# 69717    24621               6              12       52       57
# 70353    33238               2               8       55       30
# 68435    14741               3               7       46       21

# %% [markdown]
# ## Grouped_B 현재경력, 전체경력, 나이

# %%
# 필터링된 결과를 저장할 빈 리스트 초기화
filtered_frames = []

# 각 'CORP_CD'에 대해 필터링 수행
for corp_cd in Grouped_B:
    # 현재 'CORP_CD'에 해당하는 행 필터링
    temp_df = DMS_STATB_CORP02[(DMS_STATB_CORP02['CORP_CD'] == int(corp_cd)) & (DMS_STATB_CORP02['REPORT_YM'] == 201912)]
    
    # 결과가 비어있지 않고, 여러 행이 있다면 'TOT_CNT'가 최대인 행만 선택
    if not temp_df.empty:
        max_tot_cnt_row = temp_df[temp_df['TOT_CNT'] == temp_df['TOT_CNT'].max()]
        filtered_frames.append(max_tot_cnt_row)

# 모든 필터링된 결과를 하나의 DataFrame으로 합치기
Grouped_B_df = pd.concat(filtered_frames)

# 결과 출력
Grouped_B_df
# Out:
#        REPORT_YM  CORP_CD  FM_GUBUN  SIDO_CD UNION_CD REFER_CD   SGG_CD  \
# 68376     201912    14188         1  6300000  D080060  C000008  30200.0
# 68463     201912    14798         1  6300000  D080170  C000008  30200.0
# 64468     201912    25944         1  6300000  D030060  C000003  30140.0
# 64491     201912    29454         1  6300000  D030060  C000003  30170.0
# 66574     201912     3212         1  6300000  D030060  C000003  30110.0
# 66576     201912     3227         1  6300000  D030060  C000003  30140.0
# 66572     201912     3209         1  6300000  D030060  C000003  30230.0
# 69690     201912    23112         1  6300000  D030060  C000003  30140.0
# 70285     201912    26019         1  6300000  D080060  C000008  30230.0
# 70309     201912    28882         1  6300000  D030060  C000003  30140.0
# 66516     201912    33436         1  6300000  D030060  C000003  30110.0
# 69719     201912    24636         1  6300000  D080170  C000008  30200.0
# 66575     201912     3214         1  6300000  D030060  C000003  30140.0
# 66578     201912     3232         1  6300000  D030060  C000003  30230.0
# 64446     201912    22478         1  6300000  D030060  C000003  30140.0
# 70267     201912    25321         1  6300000  D030060  C000003  30170.0
# 69691     201912    23212         1  6300000  D080170  C000008  30230.0
# 69692     201912    23212         2  6300000  D080170  C000008  30230.0
# 68428     201912    14731         1  6300000  D080170  C000008  30200.0
# 69712     201912    24249         1  6300000  D080170  C000008  30110.0
# 69706     201912    23536         1  6300000  D080060  C000008  30230.0
# 70271     201912    25565         1  6440000  D030110  C000003  44760.0
# 69685     201912    22098         1  6300000  D030060  C000003  30170.0
# 64469     201912    25959         1  6300000  D030060  C000003  30200.0
# 68470     201912    14823         1  6300000  D080170  C000008  30230.0
# 68395     201912    14308         1  6300000  D080060  C000008  30230.0
# 64493     201912    29828         1  6300000  D030060  C000003  30140.0
# 70331     201912    30342         1  6300000  D030060  C000003  30110.0
# 64445     201912    22477         1  6300000  D030060  C000003  30140.0
# 66573     201912     3211         1  6300000  D030060  C000003  30140.0
# 69688     201912    22308         1  6300000  D030060  C000003  30170.0
# 69640     201912    17812         1  6300000  D020060  C000002  30110.0
# 66593     201912    14046         1  6300000  D080060  C000008  30230.0
# 69649     201912    17821         1  6300000  D020060  C000002  30110.0
# 69634     201912    17808         1  6300000  D020060  C000002  30140.0
# 69654     201912    17826         1  6300000  D020060  C000002  30110.0
# 66518     201912    33770         1  6300000  D080060  C000008  30230.0
# 69680     201912    17848         1  6300000  D020060  C000002  30170.0
# 64429     201912    17797         1  6300000  D020060  C000002  30140.0
# 69647     201912    17818         1  6300000  D020060  C000002  30170.0
# 64400     201912    17773         1  6300000  D020060  C000002  30170.0
# 69632     201912    17807         1  6300000  D020060  C000002  30170.0
# 70355     201912    33578         1  6300000  D030060  C000003  30140.0
#
#        NOW_CAREER00  NOW_CAREER01  NOW_CAREER02  ...  SCH12  SCH13  \
# 68376             3             1             0  ...      0     26
# 68463            16             2             1  ...      0     45
# 64468            11             8             1  ...      0     24
# 64491            15             5             1  ...      0     32
# 66574            14             2             2  ...      0     24
# 66576             8             1             0  ...      0     26
# 66572             8             3             4  ...      0     27
# 69690             6             6             1  ...      0     15
# 70285             4             2             1  ...      0     18
# 70309            24             6             6  ...      0     48
# 66516             3             0             0  ...      0      4
# 69719             3             6             0  ...      0     24
# 66575             4             3             5  ...      0     27
# 66578            10             6             1  ...      0     23
# 64446            11             8             2  ...      0     28
# 70267            20             7             8  ...      0     44
# 69691             0             0             0  ...      0      1
# 69692             0             0             0  ...      0      1
# 68428             7            10             3  ...      0     39
# 69712            11             9             6  ...      0     56
# 69706            10             8             6  ...      0     38
# 70271             4             2             2  ...      0      9
# 69685            12             1             4  ...      0     21
# 64469            17             9             3  ...      0     41
# 68470             8            10             3  ...      0     44
# 68395             1             2             0  ...      0      6
# 64493            11             6             3  ...      0     25
# 70331            14             7             4  ...      0     31
# 64445            11             8             0  ...      0     36
# 66573            11             0             1  ...      0     20
# 69688             2             7             2  ...      0     20
# 69640             6             5             4  ...      0     34
# 66593            10             9            10  ...      0     52
# 69649            13            11             4  ...      0     38
# 69634            18            17            10  ...      0     45
# 69654            19            11             5  ...      0     51
# 66518            11             1             2  ...      0     20
# 69680            15             8             5  ...      0     40
# 64429            26             8            17  ...      0     63
# 69647             6             4             2  ...      0     34
# 64400             5             1             5  ...      0     26
# 69632            20            12            10  ...      0     65
# 70355             6             5             8  ...      0     20
#
#        NOW_CAREER_AVG  TOT_CAREER_AVG  AGE_AVG  TOT_CNT  SYS_REG_ID  \
# 68376               8              11       51       32      system
# 68463               4               9       51       47      system
# 64468               1               9       54       24      system
# 64491               1              10       54       32      system
# 66574               1              13       57       24      system
# 66576               4               9       54       27      system
# 66572               3              13       59       29      system
# 69690               0              15       59       15      system
# 70285               3               4       46       18      system
# 70309               1              14       61       48      system
# 66516               1               6       53        4      system
# 69719               3               6       45       24      system
# 66575               3               8       57       27      system
# 66578               2               7       49       23      system
# 64446               1              14       57       28      system
# 70267               1              10       54       44      system
# 69691               8               8       44        1      system
# 69692               7               9       57        1      system
# 68428               5              11       50       43      system
# 69712               5              10       50       57      system
# 69706               2               7       51       38      system
# 70271               1               8       54        9      system
# 69685               1              14       54       21      system
# 64469               1              11       57       41      system
# 68470               6              10       49       48      system
# 68395               9              13       55       12      system
# 64493               1               5       56       25      system
# 70331               1              14       57       31      system
# 64445               2              13       52       36      system
# 66573               4              11       57       21      system
# 69688               3              14       58       20      system
# 69640               6              11       56       39      system
# 66593               5               8       48       59      system
# 69649               2               9       52       40      system
# 69634               0               8       58       45      system
# 69654               5              11       57       61      system
# 66518               1               7       47       20      system
# 69680               3               9       55       43      system
# 64429               1              10       58       63      system
# 69647               6              13       59       37      system
# 64400               7              12       60       33      system
# 69632               3               9       56       68      system
# 70355               1              18       57       20      system
#
#                      SYS_REG_DATE  ETL_RGST_ID                  ETL_REG_DT
# 68376  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68463  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64468  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64491  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66574  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66576  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66572  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69690  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70285  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70309  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66516  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69719  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66575  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66578  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64446  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70267  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69691  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69692  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68428  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69712  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69706  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70271  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69685  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64469  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68470  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68395  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64493  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70331  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64445  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66573  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69688  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69640  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66593  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69649  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69634  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69654  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66518  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69680  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64429  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69647  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64400  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69632  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70355  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
#
# [43 rows x 148 columns]

# %% [markdown]
# #### 현재경력 7:37

# %%
# columns = Grouped_B_df.columns.tolist()

# selected_columns = [columns[1]] + columns[7:37]

# Grouped_B_df.loc[:, selected_columns]

# %% [markdown]
# #### 전체경력 37:67

# %%
# columns = Grouped_B_df.columns.tolist()

# selected_columns = [columns[1]] + columns[37:67]

# Grouped_B_df.loc[:, selected_columns]

# %% [markdown]
# #### 나이 67:127

# %%
# columns = Grouped_B_df.columns.tolist()

# selected_columns = [columns[1]] + columns[67:127]

# Grouped_B_df.loc[:, selected_columns]

# %% [markdown]
# #### 평균 140:144

# %%
columns = Grouped_B_df.columns.tolist()

selected_columns = [columns[1]] + columns[140:144]

print(Grouped_B_df.iloc[:,140:144].mean())
Grouped_B_df.loc[:, selected_columns]
# Out:
# NOW_CAREER_AVG     3.093023
# TOT_CAREER_AVG    10.255814
# AGE_AVG           54.069767
# TOT_CNT           32.046512
# dtype: float64
#        CORP_CD  NOW_CAREER_AVG  TOT_CAREER_AVG  AGE_AVG  TOT_CNT
# 68376    14188               8              11       51       32
# 68463    14798               4               9       51       47
# 64468    25944               1               9       54       24
# 64491    29454               1              10       54       32
# 66574     3212               1              13       57       24
# 66576     3227               4               9       54       27
# 66572     3209               3              13       59       29
# 69690    23112               0              15       59       15
# 70285    26019               3               4       46       18
# 70309    28882               1              14       61       48
# 66516    33436               1               6       53        4
# 69719    24636               3               6       45       24
# 66575     3214               3               8       57       27
# 66578     3232               2               7       49       23
# 64446    22478               1              14       57       28
# 70267    25321               1              10       54       44
# 69691    23212               8               8       44        1
# 69692    23212               7               9       57        1
# 68428    14731               5              11       50       43
# 69712    24249               5              10       50       57
# 69706    23536               2               7       51       38
# 70271    25565               1               8       54        9
# 69685    22098               1              14       54       21
# 64469    25959               1              11       57       41
# 68470    14823               6              10       49       48
# 68395    14308               9              13       55       12
# 64493    29828               1               5       56       25
# 70331    30342               1              14       57       31
# 64445    22477               2              13       52       36
# 66573     3211               4              11       57       21
# 69688    22308               3              14       58       20
# 69640    17812               6              11       56       39
# 66593    14046               5               8       48       59
# 69649    17821               2               9       52       40
# 69634    17808               0               8       58       45
# 69654    17826               5              11       57       61
# 66518    33770               1               7       47       20
# 69680    17848               3               9       55       43
# 64429    17797               1              10       58       63
# 69647    17818               6              13       59       37
# 64400    17773               7              12       60       33
# 69632    17807               3               9       56       68
# 70355    33578               1              18       57       20

# %% [markdown]
# ## Grouped_C 현재경력, 전체경력, 나이

# %%
# 필터링된 결과를 저장할 빈 리스트 초기화
filtered_frames = []

# 각 'CORP_CD'에 대해 필터링 수행
for corp_cd in Grouped_C:
    # 현재 'CORP_CD'에 해당하는 행 필터링
    temp_df = DMS_STATB_CORP02[(DMS_STATB_CORP02['CORP_CD'] == int(corp_cd)) & (DMS_STATB_CORP02['REPORT_YM'] == 201912)]
    
    # 결과가 비어있지 않고, 여러 행이 있다면 'TOT_CNT'가 최대인 행만 선택
    if not temp_df.empty:
        max_tot_cnt_row = temp_df[temp_df['TOT_CNT'] == temp_df['TOT_CNT'].max()]
        filtered_frames.append(max_tot_cnt_row)

# 모든 필터링된 결과를 하나의 DataFrame으로 합치기
Grouped_C_df = pd.concat(filtered_frames)

# 결과 출력
Grouped_C_df
# Out:
#        REPORT_YM  CORP_CD  FM_GUBUN  SIDO_CD UNION_CD REFER_CD   SGG_CD  \
# 69733     201912    24773         1  6300000  D030060  C000003  30140.0
# 69663     201912    17834         1  6300000  D020060  C000002  30110.0
# 64410     201912    17782         1  6300000  D020060  C000002  30110.0
# 69657     201912    17828         1  6300000  D020060  C000002  30140.0
# 68439     201912    14750         1  6300000  D080170  C000008  30140.0
# 64439     201912    17804         1  6300000  D020060  C000002  30110.0
# 69672     201912    17841         1  6300000  D020060  C000002  30140.0
# 64488     201912    28994         1  6300000  D080170  C000008  30200.0
# 69645     201912    17816         1  6300000  D020060  C000002  30200.0
# 64398     201912    17771         1  6300000  D020060  C000002  30170.0
# 64408     201912    17779         1  6300000  D020060  C000002  30170.0
# 68448     201912    14763         1  6300000  D080170  C000008  30170.0
# 64423     201912    17793         1  6300000  D020060  C000002  30230.0
# 64422     201912    17792         1  6300000  D020060  C000002  30170.0
# 69651     201912    17823         1  6300000  D020060  C000002  30170.0
# 69656     201912    17827         1  6300000  D020060  C000002  30200.0
# 69678     201912    17846         1  6300000  D020060  C000002  30110.0
# 64401     201912    17774         1  6300000  D020060  C000002  30110.0
# 64405     201912    17777         1  6300000  D020060  C000002  30140.0
# 69637     201912    17810         1  6300000  D020060  C000002  30230.0
# 64402     201912    17775         1  6300000  D020060  C000002  30230.0
# 64437     201912    17803         1  6300000  D020060  C000002  30140.0
# 69636     201912    17809         1  6300000  D020060  C000002  30230.0
# 69670     201912    17839         1  6300000  D020060  C000002  30170.0
# 64406     201912    17778         1  6300000  D020060  C000002  30140.0
# 66513     201912    33011         1  6300000  D080170  C000008  30230.0
# 70272     201912    25568         1  6300000  D100060  C000010  30230.0
# 69662     201912    17833         1  6300000  D020060  C000002  30230.0
# 64421     201912    17791         1  6300000  D020060  C000002  30110.0
# 69639     201912    17811         1  6300000  D020060  C000002  30140.0
# 69665     201912    17835         1  6300000  D020060  C000002  30110.0
# 64436     201912    17802         1  6300000  D020060  C000002  30170.0
# 69643     201912    17814         1  6300000  D020060  C000002  30110.0
# 69644     201912    17815         1  6300000  D020060  C000002  30170.0
# 64430     201912    17799         1  6300000  D020060  C000002  30140.0
# 64413     201912    17784         1  6300000  D020060  C000002  30140.0
# 68423     201912    14717         1  6300000  D080170  C000008  30140.0
# 68419     201912    14366         1  6300000  D080060  C000008  30230.0
# 69668     201912    17838         1  6300000  D020060  C000002  30110.0
# 69661     201912    17832         1  6300000  D020060  C000002  30140.0
# 69673     201912    17842         1  6300000  D020060  C000002  30230.0
# 69666     201912    17836         1  6300000  D020060  C000002  30170.0
# 69677     201912    17845         1  6300000  D020060  C000002  30110.0
#
#        NOW_CAREER00  NOW_CAREER01  NOW_CAREER02  ...  SCH12  SCH13  \
# 69733            22             0             1  ...      0     23
# 69663            26             3             6  ...      0     56
# 64410            21            12             5  ...      0     53
# 69657             6            12             5  ...      0     40
# 68439            20            10             8  ...      0     87
# 64439            18             9             5  ...      0     44
# 69672            20            10             5  ...      0     45
# 64488             0             0             0  ...      0      3
# 69645            17             6             6  ...      0     41
# 64398            29             7             4  ...      0     53
# 64408            11             6             3  ...      0     39
# 68448            22             5            10  ...      0     75
# 64423            21            13             2  ...      0     45
# 64422            24             9             3  ...      0     47
# 69651            18             5             6  ...      0     40
# 69656            23            11             3  ...      0     60
# 69678             8             5             9  ...      0     29
# 64401            15             8             4  ...      0     40
# 64405             2             9             8  ...      0     40
# 69637            10             3             4  ...      0     39
# 64402            26             7             1  ...      0     45
# 64437             9             9            22  ...      0     50
# 69636            17            10             3  ...      0     38
# 69670            12             7             5  ...      0     41
# 64406             9             2             7  ...      0     34
# 66513             0             0             0  ...      0      1
# 70272             2             0             0  ...      0      4
# 69662            16            25             5  ...      0     53
# 64421            17             4             3  ...      0     34
# 69639            15            10             1  ...      0     39
# 69665             7             6             0  ...      0     29
# 64436            16            10             5  ...      0     49
# 69643             3            12             2  ...      0     24
# 69644            10             3             5  ...      0     34
# 64430             8             2             7  ...      0     26
# 64413            14             7             5  ...      0     43
# 68423             8             3             4  ...      0     32
# 68419             7             1             3  ...      0     25
# 69668            27             4             2  ...      0     41
# 69661            15             7             8  ...      0     54
# 69673            14             1             1  ...      0     23
# 69666            12             1             5  ...      0     34
# 69677            11             6             4  ...      0     39
#
#        NOW_CAREER_AVG  TOT_CAREER_AVG  AGE_AVG  TOT_CNT  SYS_REG_ID  \
# 69733               0               5       50       23      system
# 69663               3              10       58       58      system
# 64410               2               6       51       55      system
# 69657               3              10       55       42      system
# 68439               5              10       50       89      system
# 64439               5              13       56       53      system
# 69672               1               8       56       45      system
# 64488               5               9       51        3      system
# 69645               3               8       55       42      system
# 64398               2              10       59       56      system
# 64408               3              11       59       39      system
# 68448               5              10       51       79      system
# 64423               2               6       55       47      system
# 64422               2              10       56       52      system
# 69651               3               8       58       42      system
# 69656               2               6       58       60      system
# 69678               3              12       56       30      system
# 64401               3               8       55       43      system
# 64405               8              17       62       62      system
# 69637               5              10       56       43      system
# 64402               3              11       59       51      system
# 64437               2              11       54       51      system
# 69636               2               6       52       39      system
# 69670               4              13       58       46      system
# 64406               3              10       61       36      system
# 66513               4               6       44        1      system
# 70272               2              11       58        4      system
# 69662               2              12       59       56      system
# 64421               3               7       52       37      system
# 69639               2               8       57       41      system
# 69665               4              16       60       33      system
# 64436               5               9       58       58      system
# 69643               3               9       55       25      system
# 69644               4              12       63       37      system
# 64430               4              13       59       28      system
# 64413               4              10       55       51      system
# 68423               7              11       48       37      system
# 68419               4               9       50       25      system
# 69668               2               7       56       42      system
# 69661               4              10       58       57      system
# 69673               3               7       55       25      system
# 69666               7              12       60       46      system
# 69677               4               8       59       41      system
#
#                      SYS_REG_DATE  ETL_RGST_ID                  ETL_REG_DT
# 69733  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69663  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64410  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69657  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68439  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64439  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69672  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64488  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69645  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64398  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64408  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68448  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64423  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64422  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69651  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69656  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69678  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64401  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64405  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69637  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64402  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64437  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69636  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69670  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64406  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66513  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70272  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69662  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64421  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69639  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69665  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64436  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69643  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69644  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64430  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64413  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68423  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68419  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69668  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69661  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69673  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69666  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69677  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
#
# [43 rows x 148 columns]

# %% [markdown]
# #### 현재경력 7:37

# %%
# columns = Grouped_C_df.columns.tolist()

# selected_columns = [columns[1]] + columns[7:37]

# Grouped_C_df.loc[:, selected_columns]

# %% [markdown]
# #### 전체경력 37:67

# %%
# columns = Grouped_C_df.columns.tolist()

# selected_columns = [columns[1]] + columns[37:67]

# Grouped_C_df.loc[:, selected_columns]

# %% [markdown]
# #### 나이 67:127

# %%
# columns = Grouped_C_df.columns.tolist()

# selected_columns = [columns[1]] + columns[67:127]

# Grouped_C_df.loc[:, selected_columns]

# %% [markdown]
# #### 평균 140:144

# %%
columns = Grouped_C_df.columns.tolist()

selected_columns = [columns[1]] + columns[140:144]

print(Grouped_C_df.iloc[:,140:144].mean())
Grouped_C_df.loc[:, selected_columns]
# Out:
# NOW_CAREER_AVG     3.418605
# TOT_CAREER_AVG     9.651163
# AGE_AVG           55.744186
# TOT_CNT           42.558140
# dtype: float64
#        CORP_CD  NOW_CAREER_AVG  TOT_CAREER_AVG  AGE_AVG  TOT_CNT
# 69733    24773               0               5       50       23
# 69663    17834               3              10       58       58
# 64410    17782               2               6       51       55
# 69657    17828               3              10       55       42
# 68439    14750               5              10       50       89
# 64439    17804               5              13       56       53
# 69672    17841               1               8       56       45
# 64488    28994               5               9       51        3
# 69645    17816               3               8       55       42
# 64398    17771               2              10       59       56
# 64408    17779               3              11       59       39
# 68448    14763               5              10       51       79
# 64423    17793               2               6       55       47
# 64422    17792               2              10       56       52
# 69651    17823               3               8       58       42
# 69656    17827               2               6       58       60
# 69678    17846               3              12       56       30
# 64401    17774               3               8       55       43
# 64405    17777               8              17       62       62
# 69637    17810               5              10       56       43
# 64402    17775               3              11       59       51
# 64437    17803               2              11       54       51
# 69636    17809               2               6       52       39
# 69670    17839               4              13       58       46
# 64406    17778               3              10       61       36
# 66513    33011               4               6       44        1
# 70272    25568               2              11       58        4
# 69662    17833               2              12       59       56
# 64421    17791               3               7       52       37
# 69639    17811               2               8       57       41
# 69665    17835               4              16       60       33
# 64436    17802               5               9       58       58
# 69643    17814               3               9       55       25
# 69644    17815               4              12       63       37
# 64430    17799               4              13       59       28
# 64413    17784               4              10       55       51
# 68423    14717               7              11       48       37
# 68419    14366               4               9       50       25
# 69668    17838               2               7       56       42
# 69661    17832               4              10       58       57
# 69673    17842               3               7       55       25
# 69666    17836               7              12       60       46
# 69677    17845               4               8       59       41

# %% [markdown]
# ## Grouped_D 현재경력, 전체경력, 나이

# %%
# 필터링된 결과를 저장할 빈 리스트 초기화
filtered_frames = []

# 각 'CORP_CD'에 대해 필터링 수행
for corp_cd in Grouped_D:
    # 현재 'CORP_CD'에 해당하는 행 필터링
    temp_df = DMS_STATB_CORP02[(DMS_STATB_CORP02['CORP_CD'] == int(corp_cd)) & (DMS_STATB_CORP02['REPORT_YM'] == 201912)]
    
    # 결과가 비어있지 않고, 여러 행이 있다면 'TOT_CNT'가 최대인 행만 선택
    if not temp_df.empty:
        max_tot_cnt_row = temp_df[temp_df['TOT_CNT'] == temp_df['TOT_CNT'].max()]
        filtered_frames.append(max_tot_cnt_row)

# 모든 필터링된 결과를 하나의 DataFrame으로 합치기
Grouped_D_df = pd.concat(filtered_frames)

# 결과 출력
Grouped_D_df
# Out:
#        REPORT_YM  CORP_CD  FM_GUBUN  SIDO_CD UNION_CD REFER_CD   SGG_CD  \
# 69646     201912    17817         1  6300000  D020060  C000002  30140.0
# 69641     201912    17813         1  6300000  D020060  C000002  30110.0
# 64434     201912    17801         1  6300000  D020060  C000002  30170.0
# 64417     201912    17788         1  6300000  D020060  C000002  30110.0
# 64409     201912    17780         1  6300000  D020060  C000002  30200.0
# 69648     201912    17819         1  6300000  D020060  C000002  30230.0
# 69675     201912    17844         1  6300000  D020060  C000002  30110.0
# 64432     201912    17800         1  6300000  D020060  C000002  30170.0
# 64415     201912    17786         1  6300000  D020060  C000002  30140.0
# 66596     201912    14057         1  6300000  D080060  C000008  30140.0
# 69667     201912    17837         1  6300000  D020060  C000002  30140.0
# 64426     201912    17795         1  6300000  D020060  C000002  30140.0
# 64441     201912    17806         1  6300000  D020060  C000002  30170.0
# 69658     201912    17829         1  6300000  D020060  C000002  30200.0
# 64428     201912    17796         1  6300000  D020060  C000002  30140.0
# 64475     201912    26749         1  6300000  D080060  C000008  30230.0
# 64412     201912    17783         1  6300000  D020060  C000002  30110.0
# 64404     201912    17776         1  6300000  D020060  C000002  30110.0
# 64419     201912    17789         1  6300000  D020060  C000002  30230.0
# 64425     201912    17794         1  6300000  D020060  C000002  30170.0
# 69650     201912    17822         1  6300000  D020060  C000002  30110.0
# 69681     201912    17849         1  6300000  D020060  C000002  30170.0
# 68454     201912    14774         1  6300000  D080170  C000008  30200.0
# 64414     201912    17785         1  6300000  D020060  C000002  30140.0
# 66580     201912     3237         1  6300000  D030060  C000003  30110.0
# 69652     201912    17824         1  6300000  D020060  C000002  30200.0
# 64399     201912    17772         1  6300000  D020060  C000002  30110.0
# 66589     201912    12801         1  6300000  D080060  C000008  30230.0
# 69653     201912    17825         1  6300000  D020060  C000002  30230.0
# 64420     201912    17790         1  6300000  D020060  C000002  30230.0
# 71520     201912    38279         1  6300000  D080060  C000008  30200.0
# 64440     201912    17805         1  6300000  D020060  C000002  30230.0
# 68471     201912    14831         1  6300000  D080170  C000008  30200.0
# 64416     201912    17787         1  6300000  D020060  C000002  30140.0
# 69674     201912    17843         1  6300000  D020060  C000002  30140.0
# 64501     201912    31075         1  6300000  D030060  C000003  30140.0
# 68399     201912    14313         1  6300000  D080060  C000008  30230.0
# 69679     201912    17847         1  6300000  D020060  C000002  30140.0
# 64477     201912    27203         1  6300000  D080060  C000008  30230.0
# 69671     201912    17840         1  6300000  D020060  C000002  30140.0
# 66581     201912     3241         1  6300000  D030060  C000003  30140.0
# 69660     201912    17831         1  6300000  D020060  C000002  30230.0
#
#        NOW_CAREER00  NOW_CAREER01  NOW_CAREER02  ...  SCH12  SCH13  \
# 69646            15            13            12  ...      0     73
# 69641             7             8             3  ...      0     36
# 64434            12             7             5  ...      0     48
# 64417            16             8             3  ...      0     38
# 64409             6             2             0  ...      0     39
# 69648             7             4             4  ...      0     26
# 69675             7             4             1  ...      0     26
# 64432             7             7             5  ...      0     27
# 64415            10             7             2  ...      0     31
# 66596             8             4             2  ...      0     23
# 69667            26             9             2  ...      0     61
# 64426            16             8            12  ...      0     60
# 64441            32             4             0  ...      0     37
# 69658             8             8             4  ...      0     42
# 64428            15             5             5  ...      0     46
# 64475             4             0             1  ...      0     15
# 64412             6             8             0  ...      0     29
# 64404             5            14             3  ...      0     30
# 64419             2             4             3  ...      0     21
# 64425             9             2             1  ...      0     14
# 69650             7             6             2  ...      0     22
# 69681            15             6             3  ...      0     36
# 68454             2             2             0  ...      0      9
# 64414             5             4             4  ...      0     31
# 66580            36             4             0  ...      0     44
# 69652             8             7             4  ...      0     34
# 64399             5             6             2  ...      0     16
# 66589             2             2             1  ...      0     10
# 69653             7             4             1  ...      0     20
# 64420             4             3             2  ...      0     21
# 71520             0             1             0  ...      0      1
# 64440            14             4             2  ...      0     30
# 68471             2             6             2  ...      0     23
# 64416            15             1             3  ...      0     28
# 69674             3             7             2  ...      0     17
# 64501            12             3             1  ...      0     25
# 68399             8            10             2  ...      0     39
# 69679            14             1             3  ...      0     22
# 64477             4             5             3  ...      0     20
# 69671            13             8             1  ...      0     40
# 66581            10             0             0  ...      0     10
# 69660             7             7             4  ...      0     23
#
#        NOW_CAREER_AVG  TOT_CAREER_AVG  AGE_AVG  TOT_CNT  SYS_REG_ID  \
# 69646               6              11       58       89      system
# 69641               4              12       58       38      system
# 64434               4              10       55       52      system
# 64417               3               9       56       39      system
# 64409               7              15       59       44      system
# 69648               7              14       58       35      system
# 69675               5              16       57       28      system
# 64432               2               8       54       28      system
# 64415               3              10       55       33      system
# 66596               3               8       54       24      system
# 69667               3               9       55       66      system
# 64426               4              11       58       68      system
# 64441               0               9       54       37      system
# 69658               6              15       60       53      system
# 64428               3              11       57       50      system
# 64475               3               8       51       15      system
# 64412               6              13       58       33      system
# 64404               3              13       60       31      system
# 64419               9              14       58       34      system
# 64425               2               8       54       15      system
# 69650               5              10       55       30      system
# 69681               2               9       56       38      system
# 68454               4               9       55        9      system
# 64414               6              11       57       34      system
# 66580               1               7       53       45      system
# 69652               6              12       58       46      system
# 64399               5               9       58       21      system
# 66589               2               9       49       10      system
# 69653               5              13       55       24      system
# 64420               5              13       58       24      system
# 71520               1               1       36        1      system
# 64440               5               9       57       40      system
# 68471               5               9       48       24      system
# 64416               1              10       56       28      system
# 69674               2               8       58       19      system
# 64501               1              12       55       25      system
# 68399               2               6       47       39      system
# 69679               1               6       51       22      system
# 64477               2               7       49       20      system
# 69671               3              13       59       41      system
# 66581               0              10       52       10      system
# 69660               3               9       56       25      system
#
#                      SYS_REG_DATE  ETL_RGST_ID                  ETL_REG_DT
# 69646  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69641  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64434  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64417  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64409  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69648  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69675  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64432  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64415  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66596  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69667  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64426  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64441  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69658  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64428  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64475  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64412  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64404  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64419  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64425  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69650  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69681  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68454  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64414  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66580  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69652  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64399  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66589  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69653  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64420  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 71520  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64440  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68471  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64416  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69674  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64501  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68399  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69679  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64477  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69671  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66581  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69660  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
#
# [42 rows x 148 columns]

# %% [markdown]
# #### 현재경력 7:37

# %%
# columns = Grouped_D_df.columns.tolist()

# selected_columns = [columns[1]] + columns[7:37]

# Grouped_D_df.loc[:, selected_columns]

# %% [markdown]
# #### 전체경력 37:67

# %%
# columns = Grouped_D_df.columns.tolist()

# selected_columns = [columns[1]] + columns[37:67]

# Grouped_D_df.loc[:, selected_columns]

# %% [markdown]
# #### 나이 67:127

# %%
# columns = Grouped_D_df.columns.tolist()

# selected_columns = [columns[1]] + columns[67:127]

# Grouped_D_df.loc[:, selected_columns]

# %% [markdown]
# #### 평균 140:144

# %%
columns = Grouped_D_df.columns.tolist()

selected_columns = [columns[1]] + columns[140:144]

print(Grouped_D_df.iloc[:,140:144].mean())
Grouped_D_df.loc[:, selected_columns]
# Out:
# NOW_CAREER_AVG     3.571429
# TOT_CAREER_AVG    10.142857
# AGE_AVG           54.928571
# TOT_CNT           33.023810
# dtype: float64
#        CORP_CD  NOW_CAREER_AVG  TOT_CAREER_AVG  AGE_AVG  TOT_CNT
# 69646    17817               6              11       58       89
# 69641    17813               4              12       58       38
# 64434    17801               4              10       55       52
# 64417    17788               3               9       56       39
# 64409    17780               7              15       59       44
# 69648    17819               7              14       58       35
# 69675    17844               5              16       57       28
# 64432    17800               2               8       54       28
# 64415    17786               3              10       55       33
# 66596    14057               3               8       54       24
# 69667    17837               3               9       55       66
# 64426    17795               4              11       58       68
# 64441    17806               0               9       54       37
# 69658    17829               6              15       60       53
# 64428    17796               3              11       57       50
# 64475    26749               3               8       51       15
# 64412    17783               6              13       58       33
# 64404    17776               3              13       60       31
# 64419    17789               9              14       58       34
# 64425    17794               2               8       54       15
# 69650    17822               5              10       55       30
# 69681    17849               2               9       56       38
# 68454    14774               4               9       55        9
# 64414    17785               6              11       57       34
# 66580     3237               1               7       53       45
# 69652    17824               6              12       58       46
# 64399    17772               5               9       58       21
# 66589    12801               2               9       49       10
# 69653    17825               5              13       55       24
# 64420    17790               5              13       58       24
# 71520    38279               1               1       36        1
# 64440    17805               5               9       57       40
# 68471    14831               5               9       48       24
# 64416    17787               1              10       56       28
# 69674    17843               2               8       58       19
# 64501    31075               1              12       55       25
# 68399    14313               2               6       47       39
# 69679    17847               1               6       51       22
# 64477    27203               2               7       49       20
# 69671    17840               3              13       59       41
# 66581     3241               0              10       52       10
# 69660    17831               3               9       56       25

# %% [markdown]
# ## Grouped_E 현재경력, 전체경력, 나이

# %%
# 필터링된 결과를 저장할 빈 리스트 초기화
filtered_frames = []

# 각 'CORP_CD'에 대해 필터링 수행
for corp_cd in Grouped_E:
    # 현재 'CORP_CD'에 해당하는 행 필터링
    temp_df = DMS_STATB_CORP02[(DMS_STATB_CORP02['CORP_CD'] == int(corp_cd)) & (DMS_STATB_CORP02['REPORT_YM'] == 201912)]
    
    # 결과가 비어있지 않고, 여러 행이 있다면 'TOT_CNT'가 최대인 행만 선택
    if not temp_df.empty:
        max_tot_cnt_row = temp_df[temp_df['TOT_CNT'] == temp_df['TOT_CNT'].max()]
        filtered_frames.append(max_tot_cnt_row)

# 모든 필터링된 결과를 하나의 DataFrame으로 합치기
Grouped_E_df = pd.concat(filtered_frames)

# 결과 출력
Grouped_E_df
# Out:
#        REPORT_YM  CORP_CD  FM_GUBUN  SIDO_CD UNION_CD REFER_CD   SGG_CD  \
# 69721     201912    24638         1  6300000  D080170  C000008  30200.0
# 68462     201912    14795         1  6300000  D080170  C000008  30200.0
# 70343     201912    31351         1  6300000  D080060  C000008  30230.0
# 68432     201912    14735         1  6300000  D080170  C000008  30230.0
# 70364     201912    34918         1  6300000  D080060  C000008  30230.0
# 64456     201912    24971         1  6300000  D080060  C000008  30230.0
# 69718     201912    24635         1  6300000  D080170  C000008  30200.0
# 68386     201912    14258         1  6300000  D080060  C000008  30230.0
# 70276     201912    25661         1  6300000  D080060  C000008  30230.0
# 68369     201912    14165         1  6300000  D080060  C000008  30170.0
# 68426     201912    14726         1  6300000  D080170  C000008  30200.0
# 64487     201912    28626         1  6300000  D080060  C000008  30140.0
# 70366     201912    35261         1  6300000  D080060  C000008  30230.0
# 70349     201912    32526         1  6300000  D080170  C000008  30230.0
# 66599     201912    14071         1  6300000  D080060  C000008  30140.0
# 68436     201912    14746         1  6300000  D080170  C000008  30200.0
# 69689     201912    22964         1  6300000  D080060  C000008  30230.0
# 64444     201912    22461         1  6300000  D080060  C000008  30140.0
# 66587     201912    10917         1  6300000  D080060  C000008  30230.0
# 66591     201912    14043         1  6300000  D080060  C000008  30140.0
# 69713     201912    24335         1  6300000  D080170  C000008  30170.0
# 66600     201912    14072         1  6300000  D080060  C000008  30140.0
# 68438     201912    14749         1  6300000  D080170  C000008  30140.0
# 68447     201912    14759         1  6300000  D080170  C000008  30140.0
# 66597     201912    14065         1  6300000  D080060  C000008  30200.0
# 70320     201912    29708         1  6300000  D080060  C000008  30170.0
# 69728     201912    24679         1  6300000  D080170  C000008  30230.0
# 70317     201912    29591         1  6300000  D080170  C000008  30140.0
# 68434     201912    14736         1  6300000  D080170  C000008  30200.0
# 68452     201912    14770         1  6300000  D080170  C000008  30200.0
# 68431     201912    14734         1  6300000  D080170  C000008  30200.0
# 66579     201912     3235         1  6300000  D030060  C000003  30170.0
# 68404     201912    14327         1  6300000  D080060  C000008  30230.0
# 69686     201912    22199         1  6300000  D080170  C000008  30200.0
# 68402     201912    14323         1  6300000  D080060  C000008  30200.0
# 66604     201912    14107         1  6300000  D080060  C000008  30230.0
# 68397     201912    14309         1  6300000  D080060  C000008  30230.0
# 68458     201912    14790         1  6300000  D080170  C000008  30200.0
# 66595     201912    14055         1  6300000  D080060  C000008  30140.0
# 68451     201912    14769         1  6300000  D080170  C000008  30140.0
# 70369     201912    35995         1  6300000  D080060  C000008  30230.0
# 69723     201912    24640         1  6300000  D080170  C000008  30200.0
# 69697     201912    23236         1  6300000  D080170  C000008  30140.0
# 68421     201912    14371         1  6300000  D080060  C000008  30230.0
# 68398     201912    14311         1  6300000  D080060  C000008  30230.0
# 71510     201912    36733         1  6300000  D080170  C000008  30110.0
# 69720     201912    24637         1  6300000  D080170  C000008  30200.0
# 63558     201912    14475         1  6300000  D080060  C000008  30230.0
# 69704     201912    23534         1  6300000  D080060  C000008  30230.0
# 71517     201912    37521         1  6300000  D080060  C000008  30230.0
# 66520     201912    34242         1  6300000  D080060  C000008  30230.0
# 66524     201912    34957         1  6300000  D080060  C000008  30230.0
# 64454     201912    24451         1  6300000  D080170  C000008  30140.0
# 68384     201912    14255         1  6300000  D080060  C000008  30230.0
# 68473     201912    14847         1  6300000  D080170  C000008  30200.0
# 68387     201912    14263         1  6300000  D080060  C000008  30230.0
# 70351     201912    32945         1  6300000  D080170  C000008  30200.0
# 66584     201912     6302         1  6300000  D080060  C000008  30230.0
# 66530     201912    37361         1  6300000  D080060  C000008  30230.0
# 64455     201912    24970         1  6300000  D080060  C000008  30110.0
#
#        NOW_CAREER00  NOW_CAREER01  NOW_CAREER02  ...  SCH12  SCH13  \
# 69721             2            18             0  ...      0     41
# 68462             4             2             2  ...      0     22
# 70343             1             5             2  ...      0     20
# 68432             2             3             4  ...      0     16
# 70364             3             2             1  ...      0      6
# 64456             9             6             3  ...      0     37
# 69718             7            16             1  ...      0     35
# 68386            12             4             7  ...      0     41
# 70276             6             2             4  ...      0     24
# 68369            16             6            13  ...      0     78
# 68426             0             0             0  ...      0      5
# 64487            19             6             5  ...      0     42
# 70366             8            14             0  ...      0     22
# 70349             0             1             0  ...      0      1
# 66599             6             4             4  ...      0     25
# 68436             8             7             5  ...      0     58
# 69689            16             2             3  ...      0     41
# 64444            17             6            14  ...      0     57
# 66587             4             1             1  ...      0     15
# 66591             8            21             3  ...      0     53
# 69713            15             3             2  ...      0     22
# 66600            11             4             6  ...      0     44
# 68438             2             0             0  ...      0      5
# 68447             7             2             6  ...      0     25
# 66597             9             3             6  ...      0     50
# 70320             2             1            12  ...      0     16
# 69728             1             3             8  ...      0     18
# 70317             7             8             3  ...      0     33
# 68434            14             6             3  ...      0     44
# 68452            10             3             2  ...      0     35
# 68431            10             5             3  ...      0     47
# 66579             3             0             0  ...      0      5
# 68404             5             2             2  ...      0     29
# 69686             0             0             0  ...      0     11
# 68402             3             1             3  ...      0     13
# 66604             0             0             1  ...      0     17
# 68397             3             2             2  ...      0     22
# 68458             6             5             2  ...      0     27
# 66595             6             3             2  ...      0     18
# 68451            25             7             5  ...      0     61
# 70369             0             9            13  ...      0     22
# 69723             6            11             0  ...      0     22
# 69697             6            15             2  ...      0     54
# 68421             3             3             3  ...      0     23
# 68398             8             3             5  ...      0     35
# 71510             0             0             1  ...      0      1
# 69720             1             1            14  ...      0     45
# 63558            12             0             3  ...      0     25
# 69704             5             1             1  ...      0     18
# 71517            12             3             0  ...      0     15
# 66520            12             0             7  ...      0     21
# 66524             1             3            17  ...      0     25
# 64454             7             2             5  ...      0     53
# 68384            16             4             8  ...      0     71
# 68473             8             2             7  ...      0     22
# 68387             7             1             3  ...      0     15
# 70351             0             0             1  ...      0      2
# 66584             9             3             5  ...      0     29
# 66530             4             2            10  ...      0     16
# 64455            10             3             4  ...      0     47
#
#        NOW_CAREER_AVG  TOT_CAREER_AVG  AGE_AVG  TOT_CNT  SYS_REG_ID  \
# 69721               3               9       49       41      system
# 68462               3              10       50       22      system
# 70343               3               6       50       20      system
# 68432               5               8       51       18      system
# 70364               0               3       41        6      system
# 64456               3               6       46       37      system
# 69718               2               9       49       35      system
# 68386               3              10       50       43      system
# 70276               3               7       48       24      system
# 68369               5               8       50       90      system
# 68426              11              14       56        7      system
# 64487               1               6       50       42      system
# 70366               0               9       53       22      system
# 70349               1               3       41        1      system
# 66599               3               7       47       26      system
# 68436               6              12       51       71      system
# 69689               2               6       49       41      system
# 64444               2               8       49       57      system
# 66587               3               8       44       15      system
# 66591               4              10       49       56      system
# 69713               1               7       50       23      system
# 66600               4               9       51       48      system
# 68438               7               9       51        5      system
# 68447               4               8       48       26      system
# 66597               5              11       50       51      system
# 70320               1               7       50       16      system
# 69728               4               7       50       18      system
# 70317               2               6       50       33      system
# 68434               5              11       51       47      system
# 68452               4               8       51       35      system
# 68431               5               9       50       51      system
# 66579               3               7       53        5      system
# 68404               5              11       51       32      system
# 69686               6              12       52       11      system
# 68402               2               5       46       13      system
# 66604              13              20       54       29      system
# 68397               5              10       51       23      system
# 68458               6              10       52       31      system
# 66595               4               9       46       20      system
# 68451               3               6       48       65      system
# 70369               1               6       47       22      system
# 69723               1               7       48       22      system
# 69697               3               7       48       54      system
# 68421               2               8       48       23      system
# 68398               5              10       49       38      system
# 71510               2               2       41        1      system
# 69720               4               8       49       47      system
# 63558               2               7       48       26      system
# 69704               4               8       48       19      system
# 71517               0               8       50       15      system
# 66520               0               6       47       21      system
# 66524               1               9       50       25      system
# 64454               6              11       53       53      system
# 68384               4               9       49       74      system
# 68473               1               5       47       22      system
# 68387               2               6       51       16      system
# 70351               3               7       40        2      system
# 66584               3               7       50       29      system
# 66530               1               9       52       16      system
# 64455               4               7       50       47      system
#
#                      SYS_REG_DATE  ETL_RGST_ID                  ETL_REG_DT
# 69721  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68462  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70343  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68432  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70364  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64456  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69718  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68386  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70276  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68369  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68426  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64487  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70366  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70349  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66599  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68436  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69689  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64444  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66587  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66591  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69713  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66600  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68438  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68447  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66597  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70320  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69728  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70317  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68434  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68452  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68431  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66579  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68404  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69686  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68402  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66604  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68397  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68458  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66595  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68451  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70369  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69723  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69697  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68421  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68398  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 71510  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69720  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 63558  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 69704  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 71517  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66520  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66524  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64454  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68384  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68473  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 68387  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 70351  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66584  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 66530  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
# 64455  2020-01-10 22:00:58.000587     ETLDSADM  2020-01-14 18:38:35.000000
#
# [60 rows x 148 columns]

# %% [markdown]
# #### 현재경력 7:37

# %%
# columns = Grouped_E_df.columns.tolist()

# selected_columns = [columns[1]] + columns[7:37]

# Grouped_E_df.loc[:, selected_columns]

# %% [markdown]
# #### 전체경력 37:67

# %%
# columns = Grouped_E_df.columns.tolist()

# selected_columns = [columns[1]] + columns[37:67]

# Grouped_E_df.loc[:, selected_columns]

# %% [markdown]
# #### 나이 67:127

# %%
# columns = Grouped_E_df.columns.tolist()

# selected_columns = [columns[1]] + columns[67:127]

# Grouped_E_df.loc[:, selected_columns]

# %% [markdown]
# #### 평균 140:144

# %%
columns = Grouped_E_df.columns.tolist()

selected_columns = [columns[1]] + columns[140:144]

print(Grouped_E_df.iloc[:,140:144].mean())
Grouped_E_df.loc[:, selected_columns]
# Out:
# NOW_CAREER_AVG     3.350000
# TOT_CAREER_AVG     8.133333
# AGE_AVG           49.050000
# TOT_CNT           30.466667
# dtype: float64
#        CORP_CD  NOW_CAREER_AVG  TOT_CAREER_AVG  AGE_AVG  TOT_CNT
# 69721    24638               3               9       49       41
# 68462    14795               3              10       50       22
# 70343    31351               3               6       50       20
# 68432    14735               5               8       51       18
# 70364    34918               0               3       41        6
# 64456    24971               3               6       46       37
# 69718    24635               2               9       49       35
# 68386    14258               3              10       50       43
# 70276    25661               3               7       48       24
# 68369    14165               5               8       50       90
# 68426    14726              11              14       56        7
# 64487    28626               1               6       50       42
# 70366    35261               0               9       53       22
# 70349    32526               1               3       41        1
# 66599    14071               3               7       47       26
# 68436    14746               6              12       51       71
# 69689    22964               2               6       49       41
# 64444    22461               2               8       49       57
# 66587    10917               3               8       44       15
# 66591    14043               4              10       49       56
# 69713    24335               1               7       50       23
# 66600    14072               4               9       51       48
# 68438    14749               7               9       51        5
# 68447    14759               4               8       48       26
# 66597    14065               5              11       50       51
# 70320    29708               1               7       50       16
# 69728    24679               4               7       50       18
# 70317    29591               2               6       50       33
# 68434    14736               5              11       51       47
# 68452    14770               4               8       51       35
# 68431    14734               5               9       50       51
# 66579     3235               3               7       53        5
# 68404    14327               5              11       51       32
# 69686    22199               6              12       52       11
# 68402    14323               2               5       46       13
# 66604    14107              13              20       54       29
# 68397    14309               5              10       51       23
# 68458    14790               6              10       52       31
# 66595    14055               4               9       46       20
# 68451    14769               3               6       48       65
# 70369    35995               1               6       47       22
# 69723    24640               1               7       48       22
# 69697    23236               3               7       48       54
# 68421    14371               2               8       48       23
# 68398    14311               5              10       49       38
# 71510    36733               2               2       41        1
# 69720    24637               4               8       49       47
# 63558    14475               2               7       48       26
# 69704    23534               4               8       48       19
# 71517    37521               0               8       50       15
# 66520    34242               0               6       47       21
# 66524    34957               1               9       50       25
# 64454    24451               6              11       53       53
# 68384    14255               4               9       49       74
# 68473    14847               1               5       47       22
# 68387    14263               2               6       51       16
# 70351    32945               3               7       40        2
# 66584     6302               3               7       50       29
# 66530    37361               1               9       52       16
# 64455    24970               4               7       50       47

# %% [markdown]
# # Group별 위험운전

# %%
# CD_DTG DataFrame에 'Group' 열 추가
CD_DTG['Group'] = None

# 각 그룹과 그룹 이름을 순회하며 'Group' 열에 그룹 이름 할당
groups = [Grouped_A, Grouped_B, Grouped_C, Grouped_D, Grouped_E]
group_names = ['Grouped_A', 'Grouped_B', 'Grouped_C', 'Grouped_D', 'Grouped_E']

for group, name in zip(groups, group_names):
    # 해당 그룹에 속하는 TRANSCO_CD 값을 가진 행의 'Group' 열에 그룹 이름 할당
    CD_DTG.loc[CD_DTG['TRANSCO_CD'].isin(group), 'Group'] = name

# 'Group' 열이 None인 행들 제거
CD_DTG = CD_DTG.dropna(subset=['Group'])

# 결과 출력
CD_DTG.reset_index(drop= True)
# Out:
# /tmp/ipykernel_2726319/1289174766.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CD_DTG['Group'] = None
#      TRANSCO_CD  Speeding  Long-term speeding  Sudden acceleration  \
# 0          1375    545260                   0              3282864
# 1          1386    179172                   0              2900419
# 2          1376    225128                   0              2908411
# 3          1373    183506                   0              2851735
# 4          1384    361202                   0              2266239
# ..          ...       ...                 ...                  ...
# 211       14263         0                   0                    6
# 212       32945         2                   0                    0
# 213        6302         2                   0                    0
# 214       37361         1                   0                    0
# 215       24970         0                   0                    0
#
#      Sudden start  Sudden deceleration  Sudden stop  Sudden left turn  \
# 0             142              1492254       319892            459568
# 1             172              1214898       360479            395524
# 2             572               985675       235202            361650
# 3             756               995762       245403            333730
# 4              33              1197247       315906            416765
# ..            ...                  ...          ...               ...
# 211             0                    1            0                 0
# 212             0                    0            1                 1
# 213             0                    0            0                 0
# 214             0                    0            0                 0
# 215             0                    0            0                 0
#
#      Sudden right turn  Sudden U-turn  Sudden overtaking  Sudden lane change  \
# 0               262886          29161             229274              602963
# 1               239466          31662             178486              607664
# 2               205016          49051             187122              660407
# 3               182160          21659             204999              716121
# 4               230364          89193             150240              686505
# ..                 ...            ...                ...                 ...
# 211                  0              0                  0                   2
# 212                  0              0                  0                   0
# 213                  0              0                  0                   0
# 214                  0              0                  0                   0
# 215                  0              0                  0                   1
#
#      Total_Sum      Group
# 0      7224264  Grouped_A
# 1      6107942  Grouped_A
# 2      5818234  Grouped_A
# 3      5735831  Grouped_A
# 4      5713694  Grouped_A
# ..         ...        ...
# 211          9  Grouped_E
# 212          4  Grouped_E
# 213          2  Grouped_E
# 214          1  Grouped_E
# 215          1  Grouped_E
#
# [216 rows x 14 columns]

# %%
Group_CD_DTG = CD_DTG.groupby(['Group'])[['Speeding', 'Long-term speeding', 'Sudden acceleration', 'Sudden start', 
                                'Sudden deceleration', 'Sudden stop', 'Sudden left turn', 'Sudden right turn', 
                                'Sudden U-turn', 'Sudden overtaking', 'Sudden lane change','Total_Sum']].sum().reset_index()
Group_CD_DTG
# Out:
#        Group  Speeding  Long-term speeding  Sudden acceleration  Sudden start  \
# 0  Grouped_A   3693059                   0             26643754         29480
# 1  Grouped_B   1358500                   0              3419857          6277
# 2  Grouped_C   1285408                   0              2717134         14966
# 3  Grouped_D    895995                   0              1845035          9149
# 4  Grouped_E     27694                   0                44991           170
#
#    Sudden deceleration  Sudden stop  Sudden left turn  Sudden right turn  \
# 0             12775301      3966704           4320075            2483032
# 1               668154       224278            202088             134660
# 2               287122       127705              4828               4424
# 3               205956        92683             10898               6221
# 4                21302         8483              4643               5065
#
#    Sudden U-turn  Sudden overtaking  Sudden lane change  Total_Sum
# 0         525194            1705629             5944930   62087158
# 1          17640             107112              249802    6388368
# 2           1052               3075                7390    4453104
# 3            992               4828               20422    3092179
# 4           1685               2148               23767     139948

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.ticker as ticker


# 'Group' 열을 인덱스로 설정하고 'Total_Sum' 열 제거
A = Group_CD_DTG.set_index('Group')
A.drop(columns=['Total_Sum'], inplace=True)

# 데이터 프레임 전치 (행과 열 바꾸기)
df_transposed = A.T
# 그래프 그리기 (11대 위험운전 행동을 범례로, x축에 Group)
plt.figure(figsize=(10, 6))

color_cycle = cm.tab20(np.linspace(0, 1, 11))

for i, behavior in enumerate(df_transposed.index):
    plt.plot(df_transposed.columns, df_transposed.loc[behavior], marker='o', label=behavior, color=color_cycle[i])

plt.ylabel('Number of Incidents')
# plt.title('Comparison of 11 Dangerous Driving Behaviors Across Groups')
plt.ylabel('Number of Incidents')
plt.xlabel('Group')
plt.xticks()
plt.legend(title='Dangerous Driving Behavior', bbox_to_anchor=(1, 1))
plt.gca().ticklabel_format(style='plain', axis='y')
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.tight_layout()

plt.show()

# %%
# 'CORP_CD'와 'REPORT_YM'을 기준으로 정렬
sorted_df = DMS_STATB_CORP01.sort_values(by=['CORP_CD', 'REPORT_YM'], ascending=[True, False])

# 'CORP_CD'별로 첫 번째 행만 유지 (가장 최근 데이터)
unique_rows = sorted_df.drop_duplicates(subset='CORP_CD')

# 특정 CORP_CD 값에 대한 행만 필터링
CORP_A = unique_rows[unique_rows['CORP_CD'].isin(Grouped_A)]
CORP_A['Company'] = ['Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Freight','Freight','Taxi','Freight','Bus','Bus','Bus','Bus']
CORP_A[['CORP_CD','CORP_NM','Company']]
# df = CORP_A[['CORP_CD','CORP_NM']]
# print(df.to_string(index=False))
# Out:
# /tmp/ipykernel_2726319/1856189822.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CORP_A['Company'] = ['Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Bus','Freight','Freight','Taxi','Freight','Bus','Bus','Bus','Bus']
#        CORP_CD        CORP_NM  Company
# 53798     1373        대전버스(주)      Bus
# 53799     1374        경익운수(주)      Bus
# 53800     1375        대전운수(주)      Bus
# 53801     1376        협진운수(주)      Bus
# 53802     1377        대전교통(주)      Bus
# 53803     1378        대전승합(주)      Bus
# 53804     1380        동인여객(주)      Bus
# 53805     1381        금성교통(주)      Bus
# 53806     1382        동건운수(주)      Bus
# 53807     1383        금남교통(주)      Bus
# 53808     1384        산호교통(주)      Bus
# 53809     1385        한일버스(주)      Bus
# 53810     1386        계룡버스(주)      Bus
# 53929    14316  (유)비전물류(송암물류)  Freight
# 54005    14741        (자)백제화물  Freight
# 63210    17830        (합)제일운수     Taxi
# 53953    24621        태성운수(주)  Freight
# 59031    25288       (주)굿타임투어      Bus
# 53832    28814      유성마을버스(주)      Bus
# 59042    29993        (주)삼성투어      Bus
# 59147    33238       삼성투어협동조합      Bus

# %%
# 'Company' 열 기준으로 개수 세기

df = CORP_A[['CORP_CD','CORP_NM','Company']]
company_counts = df['Company'].value_counts()

# 그래프 그리기
plt.figure(figsize=(8, 6))
company_counts.plot(kind='bar')
# plt.title('Number of Companies by Type')
plt.xlabel('Group A Company Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# 'CORP_CD'와 'REPORT_YM'을 기준으로 정렬
sorted_df = DMS_STATB_CORP01.sort_values(by=['CORP_CD', 'REPORT_YM'], ascending=[True, False])

# 'CORP_CD'별로 첫 번째 행만 유지 (가장 최근 데이터)
unique_rows = sorted_df.drop_duplicates(subset='CORP_CD')

# 특정 CORP_CD 값에 대한 행만 필터링
CORP_E = unique_rows[unique_rows['CORP_CD'].isin(Grouped_E)]
CORP_E['Company'] = ['Bus','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight',
                     'Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight',
                     'Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Bus','Freight','Freight','Freight',
                     'Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight',
                     'Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight']
CORP_E[['CORP_CD','CORP_NM','Company']]
# df = filtered_df[['CORP_CD','CORP_NM']]
# print(df.to_string(index=False))
# Out:
# /tmp/ipykernel_2726319/3364799028.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CORP_E['Company'] = ['Bus','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight','Freight',
#        CORP_CD             CORP_NM  Company
# 53817     3235             칠성관광(주)      Bus
# 59034     6302             (주)하나통운  Freight
# 53844    10205             수림운수(주)  Freight
# 53955    10917  (주)중부물류(구,삼국유통(주))  Freight
# 53859    14043             (유)금남화물  Freight
# ...        ...                 ...      ...
# 59154    35261             (주)승리통운  Freight
# 59212    35995             경덕물류(주)  Freight
# 63233    36733             (유)대성제휴  Freight
# 59172    37361             (주)대청운수  Freight
# 59202    37521             (주)대청통운  Freight
#
# [65 rows x 3 columns]

# %%
company_counts
# Out:
# Company
# Freight    63
# Bus         2
# Name: count, dtype: int64

# %%
# 'Company' 열 기준으로 개수 세기

df = CORP_E[['CORP_CD','CORP_NM','Company']]
company_counts = df['Company'].value_counts()

# 그래프 그리기
plt.figure(figsize=(8, 6))
company_counts.plot(kind='bar')
# plt.title('Number of Companies by Type')
plt.xlabel('Group E Company Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
CD_DTG[CD_DTG['Group']=='Grouped_A'].head(4)
# Out:
#    TRANSCO_CD  Speeding  Long-term speeding  Sudden acceleration  \
# 0        1375    545260                   0              3282864
# 1        1386    179172                   0              2900419
# 2        1376    225128                   0              2908411
# 3        1373    183506                   0              2851735
#
#    Sudden start  Sudden deceleration  Sudden stop  Sudden left turn  \
# 0           142              1492254       319892            459568
# 1           172              1214898       360479            395524
# 2           572               985675       235202            361650
# 3           756               995762       245403            333730
#
#    Sudden right turn  Sudden U-turn  Sudden overtaking  Sudden lane change  \
# 0             262886          29161             229274              602963
# 1             239466          31662             178486              607664
# 2             205016          49051             187122              660407
# 3             182160          21659             204999              716121
#
#    Total_Sum      Group
# 0    7224264  Grouped_A
# 1    6107942  Grouped_A
# 2    5818234  Grouped_A
# 3    5735831  Grouped_A

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib.ticker as ticker

# # 데이터프레임을 만듭니다.
# data = CD_DTG[CD_DTG['TRANSCO_CD'].isin([1375,1386,1376,1374])].reset_index(drop=True)[['TRANSCO_CD','Sudden acceleration','Sudden deceleration','Sudden lane change']]
# df = pd.DataFrame(data)

# # 데이터를 재구조화하여 '위험운전 종류'를 기준으로 데이터를 그룹화합니다.
# df_melted = df.melt(id_vars='TRANSCO_CD', var_name='Driving Behavior', value_name='Count')

# # 멀티바 그래프를 위한 x 위치를 설정합니다.
# # 이 경우, 각 'TRANSCO_CD' 별로 막대가 그룹화됩니다.
# categories = df_melted['Driving Behavior'].unique()
# positions = np.arange(len(categories))

# new_labels = ['Company A', 'Company B', 'Company C', 'Company D']

# # 막대 그래프의 너비를 설정합니다.
# bar_width = 0.1

# # 그래프 그리기
# plt.figure(figsize=(10, 6))

# # 각 운수회사별로 막대를 그립니다.
# for i, (transco,label) in enumerate(zip(df['TRANSCO_CD'],new_labels)):
#     transco_data = df_melted[df_melted['TRANSCO_CD'] == transco]
#     plt.bar(positions + i * bar_width, transco_data['Count'], bar_width, label=label)

# # x축에 '위험운전 종류' 값을 표시합니다.
# plt.xticks(positions + bar_width, categories)

# # x축과 y축 레이블을 추가합니다.
# # plt.xlabel('Risky Driving Behavior')
# # plt.ylabel('Count')

# # 그래프 제목을 추가합니다.
# # plt.title('Count of Risky Driving Behaviors by Transportation Company')


# # 범례를 추가합니다.
# plt.legend(title='              Group A \nTransportation Company')
# plt.gca().ticklabel_format(style='plain', axis='y')
# plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

# # 그래프를 화면에 표시합니다.
# plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 데이터프레임을 만듭니다.
data = CD_DTG[CD_DTG['TRANSCO_CD'].isin([1375,1386,1376,1374])].reset_index(drop=True)[['TRANSCO_CD','Sudden acceleration','Sudden deceleration','Sudden lane change']]
df = pd.DataFrame(data)

# 데이터를 재구조화하여 '위험운전 종류'를 기준으로 데이터를 그룹화합니다.
df_melted = df.melt(id_vars='TRANSCO_CD', var_name='Driving Behavior', value_name='Count')

# TRANSCO_CD와 회사 레이블 간의 매핑
transco_to_company = {
    1375: 'Company A',
    1386: 'Company B',
    1376: 'Company C',
    1374: 'Company D'
}

# df_melted에 'Company' 열 추가
df_melted['Company'] = df_melted['TRANSCO_CD'].map(transco_to_company)

# 그래프 그리기
plt.figure(figsize=(10, 6))

# 순서를 제어하기 위해 고유한 회사 레이블 리스트 생성
companies = ['Company A', 'Company B', 'Company C', 'Company D']

# 각 회사별로 막대를 그립니다.
for i, company in enumerate(companies):
    company_data = df_melted[df_melted['Company'] == company]
    plt.bar(positions + i * bar_width, company_data['Count'], bar_width, label=company)
    
# x축에 '위험운전 종류' 값을 표시합니다.
plt.xticks(positions + bar_width, categories)

# x축과 y축 레이블을 추가합니다.
# plt.xlabel('Risky Driving Behavior')
# plt.ylabel('Count')

# 그래프 제목을 추가합니다.
# plt.title('Count of Risky Driving Behaviors by Transportation Company')

# 범례를 추가합니다.
plt.legend(title='              Group A \nTransportation Company')
plt.gca().ticklabel_format(style='plain', axis='y')
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

# 그래프를 화면에 표시합니다.
plt.show()

# %%
# pd.set_option('display.max_columns', None)

A = DMS_STATB_CORP02[(DMS_STATB_CORP02['CORP_CD'] == 1375) & (DMS_STATB_CORP02['REPORT_YM'] == 201912)]

# %%
# 현재 경력과 전체 경력에 대한 집계를 위한 수정된 함수 정의

def aggregate_career_corrected(data, prefix):
    """
    경력 데이터를 수정하여 집계하는 함수.
    
    :param data: DataFrame, 원본 데이터
    :param prefix: str, 집계할 경력 데이터의 컬럼 접두사 ('NOW_CAREER' 또는 'TOT_CAREER')
    :return: DataFrame, 집계된 경력 데이터
    """
    # 1년 미만
    data[f'{prefix}_LT1'] = data[f'{prefix}00']
    # 1년~5년
    data[f'{prefix}_1TO5'] = data[[f'{prefix}{i:02d}' for i in range(1, 6)]].sum(axis=1)
    # 5년~10년
    data[f'{prefix}_5TO10'] = data[[f'{prefix}{i:02d}' for i in range(6, 11)]].sum(axis=1)
    # 10년 이상
    data[f'{prefix}_10TO15'] = data[[f'{prefix}{i:02d}' for i in range(11, 16)]].sum(axis=1)
    data[f'{prefix}_15TO20'] = data[[f'{prefix}{i:02d}' for i in range(16, 21)]].sum(axis=1)
    data[f'{prefix}_20TO25'] = data[[f'{prefix}{i:02d}' for i in range(21, 26)]].sum(axis=1)
    # 경력 데이터의 최대 범위 확인을 위해 컬럼 목록에서 매칭되는 가장 큰 값을 찾음
    max_career_year = max([int(col.replace(prefix, '')) for col in data.columns if col.startswith(prefix) and col[len(prefix):].isdigit()])
    data[f'{prefix}_GT25'] = data[[f'{prefix}{i:02d}' for i in range(26, max_career_year + 1)]].sum(axis=1)
    
    # 필요한 컬럼만 선택
    aggregated_data = data[[f'{prefix}_LT1', f'{prefix}_1TO5', f'{prefix}_5TO10', f'{prefix}_10TO15', 
                            f'{prefix}_15TO20', f'{prefix}_20TO25',f'{prefix}_GT25']]
    
    return aggregated_data

# 현재 경력 데이터 집계 (수정)
now_career_aggregated_corrected = aggregate_career_corrected(A, 'NOW_CAREER')

# 확인을 위해 현재 경력 집계 결과의 처음 몇 줄을 출력
now_career_aggregated_corrected
# Out:
# /tmp/ipykernel_2726319/512188449.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_LT1'] = data[f'{prefix}00']
# /tmp/ipykernel_2726319/512188449.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_1TO5'] = data[[f'{prefix}{i:02d}' for i in range(1, 6)]].sum(axis=1)
# /tmp/ipykernel_2726319/512188449.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_5TO10'] = data[[f'{prefix}{i:02d}' for i in range(6, 11)]].sum(axis=1)
# /tmp/ipykernel_2726319/512188449.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_10TO15'] = data[[f'{prefix}{i:02d}' for i in range(11, 16)]].sum(axis=1)
# /tmp/ipykernel_2726319/512188449.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_15TO20'] = data[[f'{prefix}{i:02d}' for i in range(16, 21)]].sum(axis=1)
# /tmp/ipykernel_2726319/512188449.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_20TO25'] = data[[f'{prefix}{i:02d}' for i in range(21, 26)]].sum(axis=1)
# /tmp/ipykernel_2726319/512188449.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_GT25'] = data[[f'{prefix}{i:02d}' for i in range(26, max_career_year + 1)]].sum(axis=1)
#        NOW_CAREER_LT1  NOW_CAREER_1TO5  NOW_CAREER_5TO10  NOW_CAREER_10TO15  \
# 66558              34              123                33                 17
#
#        NOW_CAREER_15TO20  NOW_CAREER_20TO25  NOW_CAREER_GT25
# 66558                 30                 16                5

# %%
# 전체 경력 데이터 집계 (수정)
tot_career_aggregated_corrected = aggregate_career_corrected(A, 'TOT_CAREER')
tot_career_aggregated_corrected
# Out:
# /tmp/ipykernel_2726319/512188449.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_LT1'] = data[f'{prefix}00']
# /tmp/ipykernel_2726319/512188449.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_1TO5'] = data[[f'{prefix}{i:02d}' for i in range(1, 6)]].sum(axis=1)
# /tmp/ipykernel_2726319/512188449.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_5TO10'] = data[[f'{prefix}{i:02d}' for i in range(6, 11)]].sum(axis=1)
# /tmp/ipykernel_2726319/512188449.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_10TO15'] = data[[f'{prefix}{i:02d}' for i in range(11, 16)]].sum(axis=1)
# /tmp/ipykernel_2726319/512188449.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_15TO20'] = data[[f'{prefix}{i:02d}' for i in range(16, 21)]].sum(axis=1)
# /tmp/ipykernel_2726319/512188449.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_20TO25'] = data[[f'{prefix}{i:02d}' for i in range(21, 26)]].sum(axis=1)
# /tmp/ipykernel_2726319/512188449.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_GT25'] = data[[f'{prefix}{i:02d}' for i in range(26, max_career_year + 1)]].sum(axis=1)
#        TOT_CAREER_LT1  TOT_CAREER_1TO5  TOT_CAREER_5TO10  TOT_CAREER_10TO15  \
# 66558               4               56                49                 30
#
#        TOT_CAREER_15TO20  TOT_CAREER_20TO25  TOT_CAREER_GT25
# 66558                 41                 40               38

# %%
# 나이 데이터 집계를 위한 수정된 함수 정의

def aggregate_age_corrected(data):
    """
    나이 데이터를 수정하여 집계하는 함수.
    
    :param data: DataFrame, 원본 데이터
    :return: DataFrame, 집계된 나이 데이터
    """
    # 'AGE_AVG'와 같은 평균 값을 나타내는 컬럼을 제외하고 숫자로만 끝나는 컬럼만 선택
    age_columns = [col for col in data.columns if col.startswith('AGE') and col[3:].isdigit()]
    age_aggregated_data = pd.DataFrame(index=data.index)

    # 10살 단위로 묶기 (0~20, 20~30, ... , 70 이상)
    for i in range(0, 70, 10):
        if i == 60:
            # 60 이상 모두 합치기
            cols_to_sum = [col for col in age_columns if int(col.replace('AGE', '')) >= i]
            age_aggregated_data[f'AGE_{i}UP'] = data[cols_to_sum].sum(axis=1)
        elif 30 <= i < 60:
            # 30부터 50까지는 5살 단위로 묶기
            for j in range(i, i+10, 5):
                cols_to_sum = [col for col in age_columns if j <= int(col.replace('AGE', '')) < j+5]
                age_aggregated_data[f'AGE_{j}TO{j+4}'] = data[cols_to_sum].sum(axis=1)
        else:
            # 그 외 10살 단위로 묶기
            cols_to_sum = [col for col in age_columns if i <= int(col.replace('AGE', '')) < i+10]
            age_aggregated_data[f'AGE_{i}TO{i+9}'] = data[cols_to_sum].sum(axis=1)

    return age_aggregated_data

# 나이 데이터 집계 (수정)
age_aggregated_corrected = aggregate_age_corrected(A)

# 확인을 위해 나이 집계 결과의 처음 몇 줄을 출력
age_aggregated_corrected.head()
# Out:
#        AGE_0TO9  AGE_10TO19  AGE_20TO29  AGE_30TO34  AGE_35TO39  AGE_40TO44  \
# 66558       0.0         0.0           1           5          17          15
#
#        AGE_45TO49  AGE_50TO54  AGE_55TO59  AGE_60UP
# 66558          53          69          70      28.0

# %%
plt.figure(figsize=(15, 7))
# 현재 경력 데이터
now_career_stages = ['<1', '1-5', '5-10', '10-15', '15-20', '20-25', '>25']
now_career_counts = now_career_aggregated_corrected.iloc[0].values.tolist()


# 전체 경력 데이터
tot_career_stages = ['<1', '1-5', '5-10', '10-15', '15-20', '20-25', '>25']
tot_career_counts = tot_career_aggregated_corrected.iloc[0].values.tolist()



# 현재 경력 및 전체 경력 비교 막대 그래프
plt.bar(now_career_stages, now_career_counts, width=0.4, label='Current Career', align='center', color='skyblue')
plt.bar(tot_career_stages, tot_career_counts, width=0.4, label='Total Career', align='edge', color='orange')
# plt.title('Current vs Total Career Length Distribution')
plt.xlabel('Career (years)')
plt.ylabel('Number of Individuals')
plt.legend(title='    Group A \n Company A')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 7))
# 나이 분포 데이터
age_groups = ['0-9', '10-19', '20-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60+']
age_counts = age_aggregated_corrected.iloc[0].values.tolist()

# 나이 분포 막대 그래프
plt.bar(age_groups, age_counts, color='orange')
# plt.title('Age Distribution')
plt.xlabel('Group A Age')
plt.ylabel('Number of Individuals')

plt.tight_layout()
plt.show()

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib.ticker as ticker

# # 데이터프레임을 만듭니다.
# data = CD_DTG[CD_DTG['TRANSCO_CD'].isin([22964,24971,24679,14726])].reset_index(drop=True)[['TRANSCO_CD','Sudden acceleration','Sudden deceleration','Sudden lane change']]
# df = pd.DataFrame(data)

# # 데이터를 재구조화하여 '위험운전 종류'를 기준으로 데이터를 그룹화합니다.
# df_melted = df.melt(id_vars='TRANSCO_CD', var_name='Driving Behavior', value_name='Count')

# # 멀티바 그래프를 위한 x 위치를 설정합니다.
# # 이 경우, 각 'TRANSCO_CD' 별로 막대가 그룹화됩니다.
# categories = df_melted['Driving Behavior'].unique()
# positions = np.arange(len(categories))

# new_labels = ['Company A', 'Company B', 'Company C', 'Company D']

# # 막대 그래프의 너비를 설정합니다.
# bar_width = 0.1

# # 그래프 그리기
# plt.figure(figsize=(10, 6))

# # 각 운수회사별로 막대를 그립니다.
# for i, (transco,label) in enumerate(zip(df['TRANSCO_CD'],new_labels)):
#     transco_data = df_melted[df_melted['TRANSCO_CD'] == transco]
#     plt.bar(positions + i * bar_width, transco_data['Count'], bar_width, label=label)

# # x축에 '위험운전 종류' 값을 표시합니다.
# plt.xticks(positions + bar_width, categories)

# # x축과 y축 레이블을 추가합니다.
# # plt.xlabel('Risky Driving Behavior')
# # plt.ylabel('Count')

# # 그래프 제목을 추가합니다.
# # plt.title('Count of Risky Driving Behaviors by Transportation Company')


# # 범례를 추가합니다.
# plt.legend(title='              Group E \nTransportation Company')
# plt.gca().ticklabel_format(style='plain', axis='y')
# plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

# # 그래프를 화면에 표시합니다.
# plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 데이터프레임을 만듭니다.
data = CD_DTG[CD_DTG['TRANSCO_CD'].isin([22964,24971,24679,14726])].reset_index(drop=True)[['TRANSCO_CD','Sudden acceleration','Sudden deceleration','Sudden lane change']]
df = pd.DataFrame(data)

# 데이터를 재구조화하여 '위험운전 종류'를 기준으로 데이터를 그룹화합니다.
df_melted = df.melt(id_vars='TRANSCO_CD', var_name='Driving Behavior', value_name='Count')

# TRANSCO_CD와 회사 레이블 간의 매핑
transco_to_company = {
    24971: 'Company A',
    24679: 'Company B',
    22964: 'Company C',
    14726: 'Company D'
}

# df_melted에 'Company' 열 추가
df_melted['Company'] = df_melted['TRANSCO_CD'].map(transco_to_company)

# 그래프 그리기
plt.figure(figsize=(10, 6))

# 순서를 제어하기 위해 고유한 회사 레이블 리스트 생성
companies = ['Company A', 'Company B', 'Company C', 'Company D']

# 각 회사별로 막대를 그립니다.
for i, company in enumerate(companies):
    company_data = df_melted[df_melted['Company'] == company]
    plt.bar(positions + i * bar_width, company_data['Count'], bar_width, label=company)
    
# x축에 '위험운전 종류' 값을 표시합니다.
plt.xticks(positions + bar_width, categories)

# x축과 y축 레이블을 추가합니다.
# plt.xlabel('Risky Driving Behavior')
# plt.ylabel('Count')

# 그래프 제목을 추가합니다.
# plt.title('Count of Risky Driving Behaviors by Transportation Company')

# 범례를 추가합니다.
plt.legend(title='              Group E \nTransportation Company')
plt.gca().ticklabel_format(style='plain', axis='y')
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

# 그래프를 화면에 표시합니다.
plt.show()

# %%
# pd.set_option('display.max_columns', None)

E = DMS_STATB_CORP02[(DMS_STATB_CORP02['CORP_CD'] == 22964) & (DMS_STATB_CORP02['REPORT_YM'] == 201912)]

# %%
# 현재 경력과 전체 경력에 대한 집계를 위한 수정된 함수 정의

def aggregate_career_corrected(data, prefix):
    """
    경력 데이터를 수정하여 집계하는 함수.
    
    :param data: DataFrame, 원본 데이터
    :param prefix: str, 집계할 경력 데이터의 컬럼 접두사 ('NOW_CAREER' 또는 'TOT_CAREER')
    :return: DataFrame, 집계된 경력 데이터
    """
    # 1년 미만
    data[f'{prefix}_LT1'] = data[f'{prefix}00']
    # 1년~5년
    data[f'{prefix}_1TO5'] = data[[f'{prefix}{i:02d}' for i in range(1, 6)]].sum(axis=1)
    # 5년~10년
    data[f'{prefix}_5TO10'] = data[[f'{prefix}{i:02d}' for i in range(6, 11)]].sum(axis=1)
    # 10년 이상
    data[f'{prefix}_10TO15'] = data[[f'{prefix}{i:02d}' for i in range(11, 16)]].sum(axis=1)
    data[f'{prefix}_15TO20'] = data[[f'{prefix}{i:02d}' for i in range(16, 21)]].sum(axis=1)
    data[f'{prefix}_20TO25'] = data[[f'{prefix}{i:02d}' for i in range(21, 26)]].sum(axis=1)
    # 경력 데이터의 최대 범위 확인을 위해 컬럼 목록에서 매칭되는 가장 큰 값을 찾음
    max_career_year = max([int(col.replace(prefix, '')) for col in data.columns if col.startswith(prefix) and col[len(prefix):].isdigit()])
    data[f'{prefix}_GT25'] = data[[f'{prefix}{i:02d}' for i in range(26, max_career_year + 1)]].sum(axis=1)
    
    # 필요한 컬럼만 선택
    aggregated_data = data[[f'{prefix}_LT1', f'{prefix}_1TO5', f'{prefix}_5TO10', f'{prefix}_10TO15', 
                            f'{prefix}_15TO20', f'{prefix}_20TO25',f'{prefix}_GT25']]
    
    return aggregated_data

# 현재 경력 데이터 집계 (수정)
now_career_aggregated_corrected = aggregate_career_corrected(E, 'NOW_CAREER')

# 확인을 위해 현재 경력 집계 결과의 처음 몇 줄을 출력
now_career_aggregated_corrected
# Out:
# /tmp/ipykernel_2726319/614239560.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_LT1'] = data[f'{prefix}00']
# /tmp/ipykernel_2726319/614239560.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_1TO5'] = data[[f'{prefix}{i:02d}' for i in range(1, 6)]].sum(axis=1)
# /tmp/ipykernel_2726319/614239560.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_5TO10'] = data[[f'{prefix}{i:02d}' for i in range(6, 11)]].sum(axis=1)
# /tmp/ipykernel_2726319/614239560.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_10TO15'] = data[[f'{prefix}{i:02d}' for i in range(11, 16)]].sum(axis=1)
# /tmp/ipykernel_2726319/614239560.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_15TO20'] = data[[f'{prefix}{i:02d}' for i in range(16, 21)]].sum(axis=1)
# /tmp/ipykernel_2726319/614239560.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_20TO25'] = data[[f'{prefix}{i:02d}' for i in range(21, 26)]].sum(axis=1)
# /tmp/ipykernel_2726319/614239560.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_GT25'] = data[[f'{prefix}{i:02d}' for i in range(26, max_career_year + 1)]].sum(axis=1)
#        NOW_CAREER_LT1  NOW_CAREER_1TO5  NOW_CAREER_5TO10  NOW_CAREER_10TO15  \
# 69689              16               19                 6                  0
#
#        NOW_CAREER_15TO20  NOW_CAREER_20TO25  NOW_CAREER_GT25
# 69689                  0                  0                0

# %%
# 전체 경력 데이터 집계 (수정)
tot_career_aggregated_corrected = aggregate_career_corrected(E, 'TOT_CAREER')
tot_career_aggregated_corrected
# Out:
# /tmp/ipykernel_2726319/614239560.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_LT1'] = data[f'{prefix}00']
# /tmp/ipykernel_2726319/614239560.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_1TO5'] = data[[f'{prefix}{i:02d}' for i in range(1, 6)]].sum(axis=1)
# /tmp/ipykernel_2726319/614239560.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_5TO10'] = data[[f'{prefix}{i:02d}' for i in range(6, 11)]].sum(axis=1)
# /tmp/ipykernel_2726319/614239560.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_10TO15'] = data[[f'{prefix}{i:02d}' for i in range(11, 16)]].sum(axis=1)
# /tmp/ipykernel_2726319/614239560.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_15TO20'] = data[[f'{prefix}{i:02d}' for i in range(16, 21)]].sum(axis=1)
# /tmp/ipykernel_2726319/614239560.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_20TO25'] = data[[f'{prefix}{i:02d}' for i in range(21, 26)]].sum(axis=1)
# /tmp/ipykernel_2726319/614239560.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{prefix}_GT25'] = data[[f'{prefix}{i:02d}' for i in range(26, max_career_year + 1)]].sum(axis=1)
#        TOT_CAREER_LT1  TOT_CAREER_1TO5  TOT_CAREER_5TO10  TOT_CAREER_10TO15  \
# 69689               2               17                14                  4
#
#        TOT_CAREER_15TO20  TOT_CAREER_20TO25  TOT_CAREER_GT25
# 69689                  3                  1                0

# %%
# 나이 데이터 집계를 위한 수정된 함수 정의

def aggregate_age_corrected(data):
    """
    나이 데이터를 수정하여 집계하는 함수.
    
    :param data: DataFrame, 원본 데이터
    :return: DataFrame, 집계된 나이 데이터
    """
    # 'AGE_AVG'와 같은 평균 값을 나타내는 컬럼을 제외하고 숫자로만 끝나는 컬럼만 선택
    age_columns = [col for col in data.columns if col.startswith('AGE') and col[3:].isdigit()]
    age_aggregated_data = pd.DataFrame(index=data.index)

    # 10살 단위로 묶기 (0~20, 20~30, ... , 70 이상)
    for i in range(0, 70, 10):
        if i == 60:
            # 60 이상 모두 합치기
            cols_to_sum = [col for col in age_columns if int(col.replace('AGE', '')) >= i]
            age_aggregated_data[f'AGE_{i}UP'] = data[cols_to_sum].sum(axis=1)
        elif 30 <= i < 60:
            # 30부터 50까지는 5살 단위로 묶기
            for j in range(i, i+10, 5):
                cols_to_sum = [col for col in age_columns if j <= int(col.replace('AGE', '')) < j+5]
                age_aggregated_data[f'AGE_{j}TO{j+4}'] = data[cols_to_sum].sum(axis=1)
        else:
            # 그 외 10살 단위로 묶기
            cols_to_sum = [col for col in age_columns if i <= int(col.replace('AGE', '')) < i+10]
            age_aggregated_data[f'AGE_{i}TO{i+9}'] = data[cols_to_sum].sum(axis=1)

    return age_aggregated_data

# 나이 데이터 집계 (수정)
age_aggregated_corrected = aggregate_age_corrected(E)

# 확인을 위해 나이 집계 결과의 처음 몇 줄을 출력
age_aggregated_corrected.head()
# Out:
#        AGE_0TO9  AGE_10TO19  AGE_20TO29  AGE_30TO34  AGE_35TO39  AGE_40TO44  \
# 69689       0.0         0.0           0           2           3           5
#
#        AGE_45TO49  AGE_50TO54  AGE_55TO59  AGE_60UP
# 69689           9          11           5       6.0

# %%
plt.figure(figsize=(15, 7))
# 현재 경력 데이터
now_career_stages = ['<1', '1-5', '5-10', '10-15', '15-20', '20-25', '>25']
now_career_counts = now_career_aggregated_corrected.iloc[0].values.tolist()


# 전체 경력 데이터
tot_career_stages = ['<1', '1-5', '5-10', '10-15', '15-20', '20-25', '>25']
tot_career_counts = tot_career_aggregated_corrected.iloc[0].values.tolist()



# 현재 경력 및 전체 경력 비교 막대 그래프
plt.bar(now_career_stages, now_career_counts, width=0.4, label='Current Career', align='center', color='skyblue')
plt.bar(tot_career_stages, tot_career_counts, width=0.4, label='Total Career', align='edge', color='orange')
# plt.title('Current vs Total Career Length Distribution')
plt.xlabel('Career (years)')
plt.ylabel('Number of Individuals')
plt.legend(title='    Group E \n Company C')


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 7))
# 나이 분포 데이터
age_groups = ['0-9', '10-19', '20-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60+']
age_counts = age_aggregated_corrected.iloc[0].values.tolist()

# 나이 분포 막대 그래프
plt.bar(age_groups, age_counts, color='orange')
# plt.title('Age Distribution')
plt.xlabel('Group E Age')
plt.ylabel('Number of Individuals')

plt.tight_layout()
plt.show()
